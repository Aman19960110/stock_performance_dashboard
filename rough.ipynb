# %%
# =========================
# NIFTY 50 Symbols
# =========================
nifty_50_symbols = [
    "ADANIENT","ADANIPORTS","APOLLOHOSP","ASIANPAINT","AXISBANK",
    "BAJAJ-AUTO","BAJFINANCE","BAJAJFINSV","BPCL","BHARTIARTL",
    "BRITANNIA","CIPLA","COALINDIA","DIVISLAB","DRREDDY",
    "EICHERMOT","GRASIM","HCLTECH","HDFCBANK","HDFCLIFE",
    "HEROMOTOCO","HINDALCO","HINDUNILVR","ICICIBANK","ITC",
    "INDUSINDBK","INFY","JSWSTEEL","KOTAKBANK","LT",
    "M&M","MARUTI","NESTLEIND","NTPC","ONGC",
    "POWERGRID","RELIANCE","SBILIFE","SBIN","SUNPHARMA",
    "TCS","TATACONSUM","TATAMOTORS","TATASTEEL","TECHM",
    "TITAN","ULTRACEMCO","UPL","WIPRO","LTM"
]

# %%
len(nifty_50_symbols)
# Out:
# 50

# %%
import streamlit as st
import pandas as pd
import math
import yfinance as yf
import plotly.graph_objects as go
import utils.helpers_functions as hf

from datetime import date, timedelta
from config import Settings
from markets.us import Us_Market
from markets.india import India_Market

# %%
settings = Settings()



choice = 'US'
market, stock_df, group_size = hf.get_market(choice)

# =========================
# Group Selector
# =========================


total_groups = hf.total_groups(stock_df,group_size)


group_no = 1


df_group = hf.get_group(group_no,group_size,stock_df)

# Create label dict for plot
label_column = hf.MARKET_LABEL_COLUMNS.get(choice, 'SYMBOL')
label_dict = dict(zip(df_group['SYMBOL'], df_group[label_column])) if label_column in df_group.columns else {s: s for s in df_group['SYMBOL']}



symbols = market.get_symbols(df_group)
start_date = '2026-01-01'
end_date = '2026-04-04'
price_df = hf.get_data(symbols,start_date,end_date)

if price_df.empty:
    st.warning("No price data available.")
    st.stop()

# =========================
# Returns Calculation
# =========================
total_pct_df = hf.calculate_returs(price_df)
# Out:
# 2026-04-25 11:20:10.817 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-25 11:20:10.822 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-25 11:20:10.825 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-25 11:20:10.845 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-25 11:20:10.850 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-04-25 11:20:10.856 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-25 11:20:11.672
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run d:\PROJECTS\stock_performance_dashboard\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-25 11:20:11.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-25 11:20:11.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
price_df
# Out:
# Ticker            AAPL        ABBV        AMAT         AMD        AMGN  \
# Date
# 2026-01-02  270.756653  225.608078  268.535095  223.470001  325.385376
# 2026-01-05  267.010162  216.625458  283.965851  221.080002  318.512970
# 2026-01-06  262.114716  220.314926  295.641296  214.350006  327.897949
# 2026-01-07  260.086609  229.651733  291.836029  210.020004  339.289032
# 2026-01-08  258.797852  220.511703  281.289185  204.679993  327.838348
# ...                ...         ...         ...         ...         ...
# 2026-03-27  248.800003  207.677078  337.170013  201.990005  348.769989
# 2026-03-30  246.630005  211.366470  323.119995  196.039993  349.000000
# 2026-03-31  253.789993  215.700516  341.790009  203.429993  351.850006
# 2026-04-01  255.630005  213.211166  353.799988  210.210007  353.279999
# 2026-04-02  255.919998  207.121689  348.470001  217.500000  347.940002
#
# Ticker            AMZN        AVGO         AXP        BAC         CAT  ...  \
# Date                                                                   ...
# 2026-01-02  226.500000  346.892303  371.555389  55.635487  595.878662  ...
# 2026-01-05  233.059998  342.701141  378.603088  56.570198  613.493896  ...
# 2026-01-06  240.929993  343.050385  382.351227  56.928177  620.454346  ...
# 2026-01-07  241.559998  342.780945  377.028076  55.327225  593.996765  ...
# 2026-01-08  246.289993  331.784027  381.773071  55.864193  605.557617  ...
# ...                ...         ...         ...        ...         ...  ...
# 2026-03-27  199.339996  300.679993  291.348938  46.970001  694.078613  ...
# 2026-03-30  200.949997  293.410004  296.552490  47.230000  666.161743  ...
# 2026-03-31  208.270004  309.510010  301.526764  48.750000  707.113831  ...
# 2026-04-01  210.570007  313.489990  300.500031  49.270000  728.932251  ...
# 2026-04-02  209.770004  314.549988  300.179993  49.380001  715.857117  ...
#
# Ticker              PM         RTX        TMUS        TSLA         UNH  \
# Date
# 2026-01-02  158.881683  186.630127  198.624939  438.070007  333.804901
# 2026-01-05  158.445572  187.636765  199.898819  451.670013  339.381531
# 2026-01-06  153.787155  189.769684  197.649628  432.959991  346.277924
# 2026-01-07  153.777237  185.115143  196.345886  431.410004  339.064026
# 2026-01-08  157.404861  186.550385  196.962936  435.799988  344.174286
# ...                ...         ...         ...         ...         ...
# 2026-03-27  163.539993  189.710007  210.820007  361.829987  259.019989
# 2026-03-30  164.830002  187.149994  213.940002  355.279999  261.790009
# 2026-03-31  165.339996  192.899994  210.029999  371.750000  270.589996
# 2026-04-01  157.330002  194.720001  204.250000  381.260010  273.980011
# 2026-04-02  158.100006  196.210007  201.399994  360.589996  277.260010
#
# Ticker               V         VZ        WFC         WMT         XOM
# Date
# 2026-01-02  345.766998  39.238792  94.734390  112.529060  121.837906
# 2026-01-05  353.071930  38.957966  95.908623  112.479164  124.529961
# 2026-01-06  356.824188  39.025749  95.918571  114.105820  120.248505
# 2026-01-07  355.147644  38.861130  93.828850  112.489143  117.705444
# 2026-01-08  351.505188  39.287216  95.132439  112.838425  122.096184
# ...                ...        ...        ...         ...         ...
# 2026-03-27  295.519989  49.564514  77.190002  122.889999  170.990005
# 2026-03-30  299.540009  49.554661  76.800003  123.500000  171.470001
# 2026-03-31  302.239990  49.456142  79.610001  124.279999  169.660004
# 2026-04-01  298.510010  48.658142  80.570000  124.739998  160.779999
# 2026-04-02  300.799988  48.667999  80.599998  125.790001  160.690002
#
# [63 rows x 50 columns]

# %%
total_pct_df.to_clipboard()

# %%
def calculate_pct_rank_delta(df,n_days):
    stock_cols = df.columns.drop(["mean_pct_chg", "median_pct_change", "std", "2std"], errors='ignore')

    
    pct_rank = df[stock_cols].rank(axis=1, pct=True) * 100
    n_days_ago = pct_rank.shift(n_days).iloc[-1].astype(int)
    current_day = pct_rank.iloc[-1].astype(int)
    current_day.rename("current_day_rank",inplace=True)
    n_days_ago.rename("n_days_ago_rank",inplace=True)
    delta_df = pd.merge(current_day,n_days_ago,left_index=True,right_index=True,how='inner')
    delta_df['rank_delta'] = delta_df['current_day_rank'] - delta_df['n_days_ago_rank']
    delta_df.sort_values(by='rank_delta',ascending=False,inplace = True)
    
    return delta_df

# %%
calculate_pct_rank_delta(total_pct_df,10)
# Out:
#         current_day_rank  n_days_ago_rank  rank_delta
# Ticker
# GS                    50               28          22
# AMD                   52               34          18
# BAC                   28               12          16
# NFLX                  68               54          14
# AAPL                  48               36          12
# MS                    34               24          10
# GEV                  100               92           8
# WMT                   74               66           8
# COST                  86               78           8
# ABBV                  36               30           6
# INTC                  92               86           6
# JPM                   32               26           6
# WFC                   12                6           6
# MRK                   76               72           4
# MCD                   60               56           4
# AXP                    6                2           4
# CAT                   88               84           4
# XOM                   98               94           4
# VZ                    90               88           2
# LLY                   16               14           2
# CSCO                  62               62           0
# NVDA                  46               46           0
# UNH                   10               10           0
# V                     18               18           0
# LIN                   80               80           0
# JNJ                   82               82           0
# ORCL                   2                4          -2
# IBM                   14               16          -2
# MA                    20               22          -2
# CVX                   94               96          -2
# AMZN                  38               40          -2
# AMGN                  66               68          -2
# AMAT                  96               98          -2
# PG                    57               60          -3
# PM                    54               57          -3
# MSFT                   4                8          -4
# KO                    72               76          -4
# PEP                   70               74          -4
# RTX                   64               70          -6
# HD                    42               48          -6
# LRCX                  84               90          -6
# AVGO                  30               38          -8
# GOOGL                 44               52          -8
# TMUS                  56               64          -8
# GOOG                  40               50         -10
# GE                    22               32         -10
# TSLA                   8               20         -12
# PLTR                  26               42         -16
# META                  24               44         -20
# MU                    78              100         -22

# %%
round((pct_rank - pct_rank.shift(10)),2).iloc[-1].sort_values(ascending=False)
# Out:
# Ticker
# GS       0.22
# AMD      0.18
# BAC      0.16
# NFLX     0.14
# AAPL     0.12
# MS       0.10
# GEV      0.08
# WMT      0.08
# COST     0.08
# ABBV     0.06
# INTC     0.06
# JPM      0.06
# WFC      0.06
# MRK      0.04
# MCD      0.04
# AXP      0.04
# CAT      0.04
# XOM      0.04
# VZ       0.02
# LLY      0.02
# CSCO     0.00
# NVDA     0.00
# UNH      0.00
# V        0.00
# LIN      0.00
# JNJ      0.00
# PG      -0.02
# ORCL    -0.02
# MA      -0.02
# IBM     -0.02
# AMZN    -0.02
# AMGN    -0.02
# AMAT    -0.02
# CVX     -0.02
# KO      -0.04
# MSFT    -0.04
# PM      -0.04
# PEP     -0.04
# RTX     -0.06
# HD      -0.06
# LRCX    -0.06
# AVGO    -0.08
# GOOGL   -0.08
# TMUS    -0.08
# GOOG    -0.10
# GE      -0.10
# TSLA    -0.12
# PLTR    -0.16
# META    -0.20
# MU      -0.22
# Name: 2026-04-02 00:00:00, dtype: float64

# %%
from nselib import capital_market

# %%
capital_market.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      EQ
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3     3BBLACKBIO                    3B Blackbio Dx Limited      EQ
# 4      3IINFOLTD                       3i Infotech Limited      EQ
# ...          ...                                       ...     ...
# 2371    ZSARACOM        Saraswati Commercial India Limited      EQ
# 2372       ZUARI              Zuari Agro Chemicals Limited      EQ
# 2373    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 2374   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 2375   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# 3         20-APR-2026           10
# 4         22-OCT-2021           10
# ...               ...          ...
# 2371      20-APR-2026           10
# 2372      27-NOV-2012           10
# 2373      12-APR-1995           10
# 2374      18-APR-2000            1
# 2375      13-NOV-2009            2
#
# [2376 rows x 5 columns]

# %%
import yfinance as yf
yf.Ticker('reliance.ns').info
# Out:
# {'address1': 'Maker Chambers IV',
#  'address2': '3rd Floor 222 Nariman Point',
#  'city': 'Mumbai',
#  'zip': '400021',
#  'country': 'India',
#  'phone': '91 22 3555 5000',
#  'fax': '91 22 2204 2268',
#  'website': 'https://www.ril.com',
#  'industry': 'Oil & Gas Refining & Marketing',
#  'industryKey': 'oil-gas-refining-marketing',
#  'industryDisp': 'Oil & Gas Refining & Marketing',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'Reliance Industries Limited engages in the hydrocarbon exploration and production, oil and chemicals, retail, and digital service businesses worldwide. It operates through Oil to Chemicals, Oil and Gas, Retail, Digital Services, and Others segments. The company offers refining and marketing products, including liquefied petroleum gas, propylene, naphtha, gasoline, jet/aviation turbine fuel, kerosine oil, diesel, sulphur, and petroleum coke. It also provides polymers, including high-density and low-density polyethylene (PE), linear low-density PE, homopolymer, random and impact copolymer, and polyvinyl chloride; fibre intermediates, such as purified terephthalic acid, and ethylene glycols and oxide; aromatics, such as paraxylene, ortho xylene, benzene, and linear alkyl benzene and paraffin; and textiles comprising fabrics, apparel, and auto furnishings. In addition, the company offers elastomers, such as polybutadiene rubber, styrene butadiene rubber, and butyl rubber; fibre and yarn polyesters; and bioenergy solutions, consisting of compressed biogas, and pellets and briquettes. Further, it engages in oil and gas exploration and production activities; and operates various stores comprising supermarket, hypermarket, wholesale cash and carry, specialty, and online stores, as well as stores that offer apparel, beauty and cosmetics, accessories, footwear, consumer electronics, and others. Additionally, the company operates media and entertainment platforms, and Network18 and television channels; publishes magazines; and offers highway hospitality and fleet management services. It also provides digital services, including connectivity, fibre, mobile devices, apps, business, and other digital solutions. The company was founded in 1957 and is based in Mumbai, India.',
#  'fullTimeEmployees': 404501,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Mukesh Dhirubhai Ambani',
#    'age': 68,
#    'title': 'Chairman & MD',
#    'yearBorn': 1957,
#    'fiscalYear': 2026,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Nikhil Rasiklal Meswani',
#    'age': 59,
#    'title': 'Executive Director',
#    'yearBorn': 1966,
#    'fiscalYear': 2026,
#    'totalPay': 250000000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hital Rasiklal Meswani',
#    'age': 57,
#    'title': 'Executive Director',
#    'yearBorn': 1968,
#    'fiscalYear': 2026,
#    'totalPay': 250000000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Panda Madhusudana Siva Prasad',
#    'age': 73,
#    'title': 'Executive Director',
#    'yearBorn': 1952,
#    'fiscalYear': 2026,
#    'totalPay': 205800000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Anant Mukesh Ambani',
#    'age': 30,
#    'title': 'Whole-Time Director',
#    'yearBorn': 1995,
#    'fiscalYear': 2026,
#    'totalPay': 123900000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Parul  Sharma',
#    'title': 'Group President',
#    'fiscalYear': 2026,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Srikanth  Venkatachari',
#    'age': 59,
#    'title': 'Chief Financial Officer',
#    'yearBorn': 1966,
#    'fiscalYear': 2026,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mahesh  Marve',
#    'title': 'Head of Research & Technology',
#    'fiscalYear': 2026,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hemen Kanu Modi',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2026,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Savithri  Parekh',
#    'title': 'Company Secretary & Compliance Officer',
#    'fiscalYear': 2026,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 9,
#  'compensationRisk': 7,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 9,
#  'governanceEpochDate': 1780272000,
#  'compensationAsOfEpochDate': 1798675200,
#  'irWebsite': 'http://ril.com/html/investor/investor.html',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 1320.0,
#  'open': 1307.7,
#  'dayLow': 1300.3,
#  'dayHigh': 1327.8,
#  'regularMarketPreviousClose': 1320.0,
#  'regularMarketOpen': 1307.7,
#  'regularMarketDayLow': 1300.3,
#  'regularMarketDayHigh': 1327.8,
#  'dividendRate': 6.0,
#  'dividendYield': 0.45,
#  'exDividendDate': 1780617600,
#  'payoutRatio': 0.0921,
#  'fiveYearAvgDividendYield': 0.44,
#  'beta': 0.244,
#  'trailingPE': 22.034864,
#  'forwardPE': 18.203043,
#  'volume': 23302177,
#  'regularMarketVolume': 23302177,
#  'averageVolume': 20092555,
#  'averageVolume10days': 16248918,
#  'averageDailyVolume10Day': 16248918,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 17789788094464,
#  'nonDilutedMarketCap': 17862863876880,
#  'fiftyTwoWeekLow': 1290.0,
#  'fiftyTwoWeekHigh': 1611.8,
#  'allTimeHigh': 1611.8,
#  'allTimeLow': 5.428648,
#  'priceToSalesTrailing12Months': 1.6826966,
#  'fiftyDayAverage': 1365.774,
#  'twoHundredDayAverage': 1428.698,
#  'trailingAnnualDividendRate': 6.0,
#  'trailingAnnualDividendYield': 0.0045454544,
#  'currency': 'INR',
#  'tradeable': False,
#  'enterpriseValue': 21079754014720,
#  'profitMargins': 0.0764,
#  'floatShares': 6607365088,
#  'sharesOutstanding': 13532472634,
#  'heldPercentInsiders': 0.51181,
#  'heldPercentInstitutions': 0.28861,
#  'impliedSharesOutstanding': 13532472635,
#  'bookValue': 667.995,
#  'priceToBook': 1.9679788,
#  'lastFiscalYearEnd': 1774915200,
#  'nextFiscalYearEnd': 1806451200,
#  'mostRecentQuarter': 1774915200,
#  'earningsQuarterlyGrowth': -0.126,
#  'netIncomeToCommon': 807750008832,
#  'trailingEps': 59.66,
#  'forwardEps': 72.2187,
#  'pegRatio': 0.82,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1730073600,
#  'enterpriseToRevenue': 1.994,
#  'enterpriseToEbitda': 12.294,
#  '52WeekChange': -0.06083244,
#  'SandP52WeekChange': 0.27294624,
#  'lastDividendValue': 6.0,
#  'lastDividendDate': 1780617600,
#  'quoteType': 'EQUITY',
#  'currentPrice': 1314.6,
#  'targetHighPrice': 1910.0,
#  'targetLowPrice': 1510.0,
#  'targetMeanPrice': 1696.625,
#  'targetMedianPrice': 1695.0,
#  'recommendationMean': 1.3125,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 32,
#  'totalCash': 2581470117888,
#  'totalCashPerShare': 190.761,
#  'ebitda': 1714649956352,
#  'totalDebt': 3979999969280,
#  'quickRatio': 0.585,
#  'currentRatio': 1.098,
#  'totalRevenue': 10572189925376,
#  'debtToEquity': 36.653,
#  'revenuePerShare': 781.246,
#  'returnOnAssets': 0.03672,
#  'returnOnEquity': 0.09139,
#  'grossProfits': 3685560090624,
#  'freeCashflow': 218291257344,
#  'operatingCashflow': 1921130037248,
#  'earningsGrowth': -0.126,
#  'revenueGrowth': 0.125,
#  'grossMargins': 0.34861,
#  'ebitdaMargins': 0.16218,
#  'operatingMargins': 0.099750005,
#  'financialCurrency': 'INR',
#  'symbol': 'RELIANCE.NS',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'marketState': 'POSTPOST',
#  'shortName': 'RELIANCE INDUSTRIES LTD',
#  'longName': 'Reliance Industries Limited',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 820467900000,
#  'exchange': 'NSI',
#  'messageBoardId': 'finmb_878373',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'gmtOffSetMilliseconds': 19800000,
#  'market': 'in_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': -0.40909275,
#  'regularMarketPrice': 1314.6,
#  'regularMarketChange': -5.4000244,
#  'regularMarketDayRange': '1300.3 - 1327.8',
#  'fullExchangeName': 'NSE',
#  'averageDailyVolume3Month': 20092555,
#  'fiftyTwoWeekLowChange': 24.599976,
#  'fiftyTwoWeekLowChangePercent': 0.019069748,
#  'fiftyTwoWeekRange': '1290.0 - 1611.8',
#  'fiftyTwoWeekHighChange': -297.20007,
#  'fiftyTwoWeekHighChangePercent': -0.18439016,
#  'fiftyTwoWeekChangePercent': -6.0832443,
#  'earningsTimestamp': 1777024800,
#  'earningsTimestampStart': 1784282400,
#  'earningsTimestampEnd': 1784282400,
#  'earningsCallTimestampStart': 1745592300,
#  'earningsCallTimestampEnd': 1745592300,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 59.66,
#  'epsForward': 72.2187,
#  'epsCurrentYear': 63.44052,
#  'priceEpsCurrentYear': 20.721771,
#  'fiftyDayAverageChange': -51.174072,
#  'fiftyDayAverageChangePercent': -0.037468914,
#  'twoHundredDayAverageChange': -114.09802,
#  'twoHundredDayAverageChangePercent': -0.07986154,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '1.3 - Strong Buy',
#  'corporateActions': [{'header': 'Dividend',
#    'message': 'RELIANCE.NS announced a cash dividend of INR 6.00 with an ex-date of Jun. 5, 2026',
#    'meta': {'eventType': 'DIVIDEND',
#     'dateEpochMs': 1780597800000,
#     'amount': '6.00'}}],
#  'regularMarketTime': 1780394400,
#  'trailingPegRatio': None}

# %%
import streamlit as st
import pandas as pd
import math
import yfinance as yf
import plotly.graph_objects as go
import utils.helpers_functions as hf

from datetime import date, timedelta
from config import Settings
from markets.us import Us_Market
from markets.india import India_Market

# %%
market, stock_df, group_size = hf.get_market('US')
# Out:
# 2026-06-05 06:47:27.213 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 06:47:27.213 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 06:47:27.214 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 06:47:27.215 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 06:47:27.216 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-06-05 06:47:27.216 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 06:47:27.407
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /workspaces/stock_performance_dashboard/.venv/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-06-05 06:47:27.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-05 06:47:27.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
group_size
# Out:
# 50

# %%
df_group = hf.get_group(1,group_size,stock_df)

# %%
data = []

for stock in market.get_symbols(df_group):
    df = yf.download(stock, period="1y", auto_adjust=False,progress=False )
    previous_52w_high = df["High"].iloc[:-1].max().iloc[0]
    current_close = df["Close"].iloc[-1].iloc[0]
    data.append({
        'stock' : stock,
        'previous_52w_high' : previous_52w_high,
        'current_close': current_close
    })

df = pd.DataFrame(data)
df['stock_above_52week_high'] = np.where(df['current_close']>=df['previous_52w_high'],1,0)
final_df = df[df['stock_above_52week_high']==1]

# %%
import numpy as np

# %%
df[df['stock_above_52week_high']==1]
# Out:
#    stock  previous_52w_high  current_close  stock_above_52week_high
# 29   CAT         936.710022     938.659973                        1
# 30  CSCO         129.419998     129.529999                        1
# 37    MS         217.029999     217.899994                        1
# 38    GS        1073.969971    1088.449951                        1

# %%
df
# Out:
#     stock  previous_52w_high  current_price
# 0    NVDA         236.539993     219.235001
# 1    AAPL         316.940002     311.670013
# 2   GOOGL         408.609985     372.549988
# 3    GOOG         404.470001     369.260010
# 4    MSFT         555.450012     427.000000
# 5    AMZN         278.559998     253.781693
# 6    META         796.250000     629.580017
# 7    AVGO         495.000000     422.329987
# 8    TSLA         498.829987     418.980011
# 9     WMT         135.160004     118.010002
# 10    LLY        1149.099976    1134.265015
# 11    JPM         337.250000     310.230011
# 12    XOM         176.410004     152.875000
# 13      V         375.510010     319.989990
# 14    JNJ         251.710007     227.904999
# 15     MU        1089.290039    1023.599976
# 16   ORCL         345.720001     234.500000
# 17     MA         601.770020     479.924988
# 18   COST        1096.500000     975.409973
# 19   NFLX         134.115005      81.760002
# 20   ABBV         244.809998     223.300003
# 21    CVX         214.710007     189.569901
# 22   PLTR         207.520004     141.074997
# 23     PG         168.050003     140.285004
# 24    BAC          57.549999      53.785000
# 25     HD         426.750000     309.070007
# 26     GE         348.480011     326.820007
# 27    AMD         546.440002     526.520020
# 28     KO          82.660004      77.989998
# 29    CAT         936.710022     939.510010
# 30   CSCO         129.419998     129.615005
# 31    MRK         125.139999     119.285004
# 32    RTX         214.500000     178.350006
# 33   AMAT         508.260010     504.309998
# 34   LRCX         346.190002     338.239990
# 35     PM         193.050003     176.240005
# 36    UNH         404.149994     396.160004
# 37     MS         217.029999     217.595093
# 38     GS        1073.969971    1088.635010
# 39    WFC          97.760002      81.239998
# 40   TMUS         261.559998     175.520004
# 41   INTC         132.750000     111.764999
# 42    IBM         332.459991     302.700012
# 43    MCD         341.750000     272.709991
# 44    GEV        1181.949951     968.672485
# 45    LIN         521.280029     506.140015
# 46    PEP         171.479996     142.100006
# 47     VZ          51.680000      44.794998
# 48    AXP         387.489990     312.035004
# 49   AMGN         391.290009     344.000000

# %%
data
# Out:
# [{'stock': 'NVDA',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'AAPL',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'GOOGL',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'GOOG',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'MSFT',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'AMZN',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'META',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'AVGO',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'TSLA',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'WMT',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'LLY',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'JPM',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'XOM',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'V',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'JNJ',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'MU',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'ORCL',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'MA',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'COST',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'NFLX',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'ABBV',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'CVX',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'PLTR',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'PG',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'BAC',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'HD',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'GE',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'AMD',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'KO',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'CAT',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'CSCO',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'MRK',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'RTX',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'AMAT',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'LRCX',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'PM',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'UNH',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'MS',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'GS',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'WFC',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'TMUS',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'INTC',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'IBM',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'MCD',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'GEV',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'LIN',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'PEP',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'VZ',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'AXP',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64},
#  {'stock': 'AMGN',
#   'previous_52w_high': np.float64(1611.800048828125),
#   'current_price': Ticker
#   RELIANCE.NS    1303.699951
#   Name: 2026-06-04 00:00:00, dtype: float64}]

# %%
import utils.helpers_functions as hf

# %%
hf.get_stocks_above_52w_high(market,df_group)
# Out:
#   stock  previous_52w_high  current_close  stock_above_52week_high
# 0   CAT         936.710022     940.479980                        1
# 1  CSCO         129.419998     130.000000                        1
# 2    MS         217.029999     218.270004                        1
# 3    GS        1073.969971    1092.609985                        1

# %%
def get_stocks_above_52w_high(market,df_group):
    data = []

    for stock in market.get_symbols(df_group):
        try:
            df = yf.download(
                stock,
                period="1y",
                auto_adjust=False,
                progress=False,
                multi_level_index=False
            )

            if df.empty:
                continue

            previous_52w_high = df["High"].iloc[:-1].max()
            current_close = df["Close"].iloc[-1]

            data.append({
                "stock": stock,
                "previous_52w_high": previous_52w_high,
                "current_close": current_close
            })

        except Exception as e:
            print(f"Error processing {stock}: {e}")

    df_result = pd.DataFrame(data)

    df_result["stock_above_52week_high"] = np.where(
        df_result["current_close"] >= df_result["previous_52w_high"],
        1,
        0
    )

    final_df = df_result[
        df_result["stock_above_52week_high"] == 1
    ].reset_index(drop=True)

    return final_df

# %%
df_group.head()
# Out:
#   SYMBOL                 SECURITY             GICS Sector  \
# 0   NVDA                   Nvidia  Information Technology
# 1   AAPL               Apple Inc.  Information Technology
# 2  GOOGL  Alphabet Inc. (Class A)  Communication Services
# 3   GOOG  Alphabet Inc. (Class C)  Communication Services
# 4   MSFT                Microsoft  Information Technology
#
#                             GICS Sub-Industry      Headquarters Location  \
# 0                              Semiconductors    Santa Clara, California
# 1  Technology Hardware, Storage & Peripherals      Cupertino, California
# 2                Interactive Media & Services  Mountain View, California
# 3                Interactive Media & Services  Mountain View, California
# 4                            Systems Software        Redmond, Washington
#
#    Date added      CIK Founded     MarketCap
# 0  2001-11-30  1045810    1993  4.514654e+12
# 1  1982-11-30   320193    1977  3.830572e+12
# 2  2006-04-03  1652044    1998  3.739546e+12
# 3  2014-04-03  1652044    1998  3.735735e+12
# 4  1994-06-01   789019    1975  3.001863e+12

# %%
all_tickers = df_group["SYMBOL"].tolist()

prices = yf.download(
    all_tickers,
    period="1y",
    auto_adjust=True,
    progress=False
)["Close"]

# %%
returns = (
    prices.iloc[-1] / prices.iloc[0] - 1
) * 100

returns = returns.reset_index()
returns.columns = ["SYMBOL", "Return (%)"]

sector_df = (
    df_group[["SYMBOL", "GICS Sector"]]
    .merge(returns, on="SYMBOL")
    .groupby("GICS Sector")["Return (%)"]
    .mean()
    .reset_index()
    .sort_values("Return (%)", ascending=False)
)

# %%
import plotly.express as px
fig = px.bar(
    sector_df,
    x="Return (%)",
    y="Sector",
    orientation="h",
    title="Equal Weighted Sector Performance (1Y)"
)

st.plotly_chart(fig, use_container_width=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 import plotly.express as px
# ----> 2 fig = px.bar(
#       3     sector_df,
#       4     x="Return (%)",
#       5     y="Sector",
#
# File /workspaces/stock_performance_dashboard/.venv/lib/python3.11/site-packages/plotly/express/_chart_types.py:381, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, subtitle, template, width, height)
#     332 def bar(
#     333     data_frame=None,
#     334     x=None,
#    (...)    375     height=None,
#     376 ) -> go.Figure:
#     377     """
#     378     In a bar plot, each row of `data_frame` is represented as a rectangular
#     379     mark.
#     380     """
# --> 381     return make_figure(
#     382         args=locals(),
#     383         constructor=go.Bar,
#     384         trace_patch=dict(textposition="auto"),
#     385         layout_patch=dict(barmode=barmode),
#     386     )
#
# File /workspaces/stock_performance_dashboard/.venv/lib/python3.11/site-packages/plotly/express/_core.py:2511, in make_figure(args, constructor, trace_patch, layout_patch)
#    2508 layout_patch = layout_patch or {}
#    2509 apply_default_cascade(args, constructor=constructor)
# -> 2511 args = build_dataframe(args, constructor)
#    2512 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2513     args = process_dataframe_hierarchy(args)
#
# File /workspaces/stock_performance_dashboard/.venv/lib/python3.11/site-packages/plotly/express/_core.py:1757, in build_dataframe(args, constructor)
#    1754     args["color"] = None
#    1755 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1757 df_output, wide_id_vars = process_args_into_dataframe(
#    1758     args,
#    1759     wide_mode,
#    1760     var_name,
#    1761     value_name,
#    1762     is_pd_like,
#    1763     native_namespace,
#    1764 )
#    1765 df_output: nw.DataFrame
#    1766 # now that `df_output` exists and `args` contains only references, we complete
#    1767 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1768 # df_output
#
# File /workspaces/stock_performance_dashboard/.venv/lib/python3.11/site-packages/plotly/express/_core.py:1358, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1356         if argument == "index":
#    1357             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1358         raise ValueError(err_msg)
#    1359 elif length and (actual_len := len(df_input)) != length:
#    1360     raise ValueError(
#    1361         "All arguments should have the same length. "
#    1362         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1369         )
#    1370     )
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['GICS Sector', 'Return (%)'] but received: Sector

# %%
sector_df
# Out:
#               GICS Sector  Return (%)
# 7  Information Technology  207.147721
# 6             Industrials   78.079585
# 3                  Energy   48.705765
# 5             Health Care   44.510886
# 4              Financials   23.716085
# 0  Communication Services   17.876668
# 1  Consumer Discretionary   11.404482
# 8               Materials    9.360940
# 2        Consumer Staples    5.118449

# %%
import pandas as pd
import yfinance as yf
import plotly.express as px

def get_sector_performance(df_group):
    sector_returns = []

    for sector, group in df_group.groupby("GICS Sector"):

        tickers = group["SYMBOL"].tolist()

        try:
            prices = yf.download(
                tickers,
                period="1y",
                auto_adjust=True,
                progress=False
            )["Close"]

            # Handle single ticker sectors
            if isinstance(prices, pd.Series):
                prices = prices.to_frame()

            stock_returns = (
                prices.iloc[-1] / prices.iloc[0] - 1
            ) * 100

            sector_return = stock_returns.mean()

            sector_returns.append({
                "Sector": sector,
                "Return (%)": round(sector_return, 2)
            })

        except Exception as e:
            print(f"Error in {sector}: {e}")

    return pd.DataFrame(sector_returns).sort_values(
        "Return (%)",
        ascending=False
    )

# %%
sector_df = get_sector_performance(df_group)

fig = px.bar(
    sector_df,
    x="Return (%)",
    y="Sector",
    orientation="h",
    title="Equal Weighted Sector Performance (1Y)"
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 11
#       7     orientation="h",
#       8     title="Equal Weighted Sector Performance (1Y)"
#       9 )
#      10
# ---> 11 fig.show()
#
# File /workspaces/stock_performance_dashboard/.venv/lib/python3.11/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File /workspaces/stock_performance_dashboard/.venv/lib/python3.11/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
import pandas as pd
import yfinance as yf
import time
data = pd.read_csv('stock_list\stock_list.csv',index_col=0)

# %%
import yfinance as yf
import pandas as pd

sector_df = []

for row in data.itertuples():
    symbol = row.SYMBOL + ".NS"
    print(f"Fetching: {symbol}...")
    
    try:
        # This line might trigger the internal yfinance AttributeError/HTTPError
        ticker_info = yf.Ticker(symbol).info
        
        # Use .get() inside the try block to handle missing 'sector' keys safely
        sector = ticker_info.get('sector', 'Unknown')
        
        sector_df.append({
            'SYMBOL': row.SYMBOL,
            'Sector': sector
        })
        
    except Exception as e:
        # Catches the yfinance internal 404 bug and continues the loop
        print(f"❌ Error fetching {symbol} (Skipping): {e}")
        
        # Optional: Append 'Unknown' instead of skipping so your row count matches
        sector_df.append({
            'SYMBOL': row.SYMBOL,
            'Sector': 'Unknown'
        })

# Convert the final list back to a DataFrame
final_sector_df = pd.DataFrame(sector_df)
# Out:
# Fetching: 20MICRONS.NS...
# Fetching: 21STCENMGM.NS...
# Fetching: 360ONE.NS...
# Fetching: 3IINFOLTD.NS...
# Fetching: 3MINDIA.NS...
# Fetching: 3PLAND.NS...
# Fetching: 5PAISA.NS...
# Fetching: 63MOONS.NS...
# Fetching: A2ZINFRA.NS...
# Fetching: AAATECH.NS...
# Fetching: AADHARHFC.NS...
# Fetching: AAKASH.NS...
# Fetching: AAREYDRUGS.NS...
# Fetching: AARON.NS...
# Fetching: AARTECH.NS...
# Fetching: AARTIDRUGS.NS...
# Fetching: AARTIIND.NS...
# Fetching: AARTIPHARM.NS...
# Fetching: AARTISURF.NS...
# Fetching: AARVI.NS...
# Fetching: AAVAS.NS...
# Fetching: ABAN.NS...
# Fetching: ABB.NS...
# Fetching: ABBOTINDIA.NS...
# Fetching: ABCAPITAL.NS...
# Fetching: ABCOTS.NS...
# Fetching: ABDL.NS...
# Fetching: ABFRL.NS...
# Fetching: ABINFRA.NS...
# Fetching: ABLBL.NS...
# Fetching: ABMINTLLTD.NS...
# Fetching: ABREL.NS...
# Fetching: ABSLAMC.NS...
# Fetching: ACC.NS...
# Fetching: ACCELYA.NS...
# Fetching: ACCURACY.NS...
# Fetching: ACE.NS...
# Fetching: ACEINTEG.NS...
# Fetching: ACI.NS...
# Fetching: ACL.NS...
# Fetching: ACMESOLAR.NS...
# Fetching: ACUTAAS.NS...
# Fetching: ADANIENSOL.NS...
# Fetching: ADANIENT.NS...
# Fetching: ADANIGREEN.NS...
# Fetching: ADANIPORTS.NS...
# Fetching: ADANIPOWER.NS...
# Fetching: ADFFOODS.NS...
# Fetching: ADL.NS...
# Fetching: ADOR.NS...
# Fetching: ADROITINFO.NS...
# Fetching: ADSL.NS...
# Fetching: ADVAIT.NS...
# Fetching: ADVANCE.NS...
# Fetching: ADVANIHOTR.NS...
# Fetching: ADVENTHTL.NS...
# Fetching: ADVENZYMES.NS...
# Fetching: AEGISLOG.NS...
# Fetching: AEGISVOPAK.NS...
# Fetching: AEQUS.NS...
# Fetching: AEROENTER.NS...
# Fetching: AEROFLEX.NS...
# Fetching: AERONEU.NS...
# Fetching: AETHER.NS...
# Fetching: AFCONS.NS...
# Fetching: AFFLE.NS...
# Fetching: AFFORDABLE.NS...
# Fetching: AFIL.NS...
# Fetching: AFSL.NS...
# Fetching: AGARIND.NS...
# Fetching: AGARWALEYE.NS...
# Fetching: AGI.NS...
# Fetching: AGIIL.NS...
# Fetching: AGRITECH.NS...
# Fetching: AGROPHOS.NS...
# Fetching: AGSTRA.NS...
# Fetching: AHCL.NS...
# Fetching: AHLADA.NS...
# Fetching: AHLEAST.NS...
# Fetching: AHLUCONT.NS...
# Fetching: AIAENG.NS...
# Fetching: AIIL.NS...
# Fetching: AIRAN.NS...
# Fetching: AIROLAM.NS...
# Fetching: AJANTPHARM.NS...
# Fetching: AJAXENGG.NS...
# Fetching: AJMERA.NS...
# Fetching: AJOONI.NS...
# Fetching: AKASH.NS...
# Fetching: AKG.NS...
# Fetching: AKI.NS...
# Fetching: AKSHAR.NS...
# Fetching: AKSHARCHEM.NS...
# Fetching: AKSHOPTFBR.NS...
# Fetching: AKUMS.NS...
# Fetching: AKZOINDIA.NS...
# Fetching: ALANKIT.NS...
# Fetching: ALBERTDAVD.NS...
# Fetching: ALEMBICLTD.NS...
# Fetching: ALGOQUANT.NS...
# Fetching: ALICON.NS...
# Fetching: ALIVUS.NS...
# Fetching: ALKALI.NS...
# Fetching: ALKEM.NS...
# Fetching: ALKYLAMINE.NS...
# Fetching: ALLCARGO.NS...
# Fetching: ALLDIGI.NS...
# Fetching: ALLTIME.NS...
# Fetching: ALMONDZ.NS...
# Fetching: ALOKINDS.NS...
# Fetching: ALPA.NS...
# Fetching: ALPHAGEO.NS...
# Fetching: AMAGI.NS...
# Fetching: AMANTA.NS...
# Fetching: AMBER.NS...
# Fetching: AMBICAAGAR.NS...
# Fetching: AMBIKCO.NS...
# Fetching: AMBUJACEM.NS...
# Fetching: AMDIND.NS...
# Fetching: AMJLAND.NS...
# Fetching: AMNPLST.NS...
# Fetching: AMRUTANJAN.NS...
# Fetching: ANANDRATHI.NS...
# Fetching: ANANTRAJ.NS...
# Fetching: ANDHRAPAP.NS...
# Fetching: ANDHRSUGAR.NS...
# Fetching: ANGELONE.NS...
# Fetching: ANIKINDS.NS...
# Fetching: ANKITMETAL.NS...
# Fetching: ANMOL.NS...
# Fetching: ANSALAPI.NS...
# Fetching: ANTELOPUS.NS...
# Fetching: ANTGRAPHIC.NS...
# Fetching: ANTHEM.NS...
# Fetching: ANUHPHR.NS...
# Fetching: ANUP.NS...
# Fetching: ANURAS.NS...
# Fetching: APARINDS.NS...
# Fetching: APCL.NS...
# Fetching: APCOTEXIND.NS...
# Fetching: APEX.NS...
# Fetching: APLAPOLLO.NS...
# Fetching: APLLTD.NS...
# Fetching: APOLLO.NS...
# Fetching: APOLLOHOSP.NS...
# Fetching: APOLLOPIPE.NS...
# Fetching: APOLLOTYRE.NS...
# Fetching: APOLSINHOT.NS...
# Fetching: APTECHT.NS...
# Fetching: APTUS.NS...
# Fetching: ARCHIDPLY.NS...
# Fetching: ARCHIES.NS...
# Fetching: ARE&M.NS...
# Fetching: ARENTERP.NS...
# Fetching: ARFIN.NS...
# Fetching: ARIES.NS...
# Fetching: ARIHANTCAP.NS...
# Fetching: ARIHANTSUP.NS...
# Fetching: ARISINFRA.NS...
# ❌ Error fetching ARISINFRA.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: ARKADE.NS...
# Fetching: ARMANFIN.NS...
# Fetching: AROGRANITE.NS...
# Fetching: ARROWGREEN.NS...
# Fetching: ARSHIYA.NS...
# Fetching: ARSSBL.NS...
# Fetching: ARTEMISMED.NS...
# Fetching: ARTNIRMAN.NS...
# Fetching: ARVEE.NS...
# Fetching: ARVIND.NS...
# Fetching: ARVINDFASN.NS...
# Fetching: ARVSMART.NS...
# Fetching: ASAHIINDIA.NS...
# Fetching: ASAHISONG.NS...
# Fetching: ASAL.NS...
# Fetching: ASALCBR.NS...
# Fetching: ASHAPURMIN.NS...
# Fetching: ASHIANA.NS...
# Fetching: ASHIMASYN.NS...
# Fetching: ASHOKA.NS...
# Fetching: ASHOKAMET.NS...
# Fetching: ASHOKLEY.NS...
# Fetching: ASIANENE.NS...
# Fetching: ASIANHOTNR.NS...
# Fetching: ASIANPAINT.NS...
# Fetching: ASIANTILES.NS...
# Fetching: ASKAUTOLTD.NS...
# Fetching: ASMS.NS...
# Fetching: ASPINWALL.NS...
# Fetching: ASTEC.NS...
# Fetching: ASTERDM.NS...
# Fetching: ASTRAL.NS...
# Fetching: ASTRAMICRO.NS...
# Fetching: ASTRAZEN.NS...
# Fetching: ASTRON.NS...
# Fetching: ATALREAL.NS...
# Fetching: ATAM.NS...
# Fetching: ATGL.NS...
# Fetching: ATHERENERG.NS...
# Fetching: ATL.NS...
# Fetching: ATLANTAA.NS...
# Fetching: ATLANTAELE.NS...
# Fetching: ATLASCYCLE.NS...
# Fetching: ATUL.NS...
# Fetching: ATULAUTO.NS...
# Fetching: AUBANK.NS...
# Fetching: AURIGROW.NS...
# Fetching: AURIONPRO.NS...
# Fetching: AUROPHARMA.NS...
# Fetching: AURUM.NS...
# Fetching: AUSOMENT.NS...
# Fetching: AUTOAXLES.NS...
# Fetching: AUTOIND.NS...
# Fetching: AVADHSUGAR.NS...
# Fetching: AVALON.NS...
# Fetching: AVANTEL.NS...
# Fetching: AVANTIFEED.NS...
# Fetching: AVG.NS...
# Fetching: AVL.NS...
# Fetching: AVONMORE.NS...
# Fetching: AVROIND.NS...
# Fetching: AVTNPL.NS...
# Fetching: AWFIS.NS...
# Fetching: AWHCL.NS...
# Fetching: AWL.NS...
# Fetching: AXISBANK.NS...
# Fetching: AXISCADES.NS...
# Fetching: AXITA.NS...
# Fetching: AYMSYNTEX.NS...
# Fetching: AZAD.NS...
# Fetching: BAFNAPH.NS...
# Fetching: BAGFILMS.NS...
# Fetching: BAIDFIN.NS...
# Fetching: BAJAJ-AUTO.NS...
# Fetching: BAJAJCON.NS...
# Fetching: BAJAJELEC.NS...
# Fetching: BAJAJFINSV.NS...
# Fetching: BAJAJHCARE.NS...
# Fetching: BAJAJHFL.NS...
# Fetching: BAJAJHIND.NS...
# Fetching: BAJAJHLDNG.NS...
# Fetching: BAJAJINDEF.NS...
# Fetching: BAJEL.NS...
# Fetching: BAJFINANCE.NS...
# Fetching: BALAJEE.NS...
# Fetching: BALAJITELE.NS...
# Fetching: BALAMINES.NS...
# Fetching: BALAXI.NS...
# Fetching: BALKRISHNA.NS...
# Fetching: BALKRISIND.NS...
# Fetching: BALMLAWRIE.NS...
# Fetching: BALPHARMA.NS...
# Fetching: BALRAMCHIN.NS...
# Fetching: BALUFORGE.NS...
# Fetching: BANARBEADS.NS...
# Fetching: BANARISUG.NS...
# Fetching: BANCOINDIA.NS...
# Fetching: BANDHANBNK.NS...
# Fetching: BANG.NS...
# Fetching: BANKA.NS...
# Fetching: BANKBARODA.NS...
# Fetching: BANKINDIA.NS...
# Fetching: BANSALWIRE.NS...
# Fetching: BANSWRAS.NS...
# Fetching: BASF.NS...
# Fetching: BASML.NS...
# Fetching: BATAINDIA.NS...
# Fetching: BAYERCROP.NS...
# Fetching: BBL.NS...
# Fetching: BBOX.NS...
# Fetching: BBTC.NS...
# Fetching: BBTCL.NS...
# Fetching: BCG.NS...
# Fetching: BCLIND.NS...
# Fetching: BCONCEPTS.NS...
# Fetching: BDL.NS...
# Fetching: BEARDSELL.NS...
# Fetching: BECTORFOOD.NS...
# Fetching: BEDMUTHA.NS...
# Fetching: BEL.NS...
# Fetching: BELLACASA.NS...
# Fetching: BELRISE.NS...
# Fetching: BEML.NS...
# Fetching: BEPL.NS...
# Fetching: BERGEPAINT.NS...
# Fetching: BESTAGRO.NS...
# Fetching: BETA.NS...
# Fetching: BFINVEST.NS...
# Fetching: BFUTILITIE.NS...
# Fetching: BGRENERGY.NS...
# Fetching: BHAGCHEM.NS...
# Fetching: BHAGERIA.NS...
# Fetching: BHAGYANGR.NS...
# Fetching: BHANDARI.NS...
# Fetching: BHARATCOAL.NS...
# Fetching: BHARATFORG.NS...
# Fetching: BHARATGEAR.NS...
# Fetching: BHARATRAS.NS...
# Fetching: BHARATSE.NS...
# Fetching: BHARATWIRE.NS...
# Fetching: BHARTIARTL.NS...
# Fetching: BHARTIHEXA.NS...
# Fetching: BHEL.NS...
# Fetching: BIGBLOC.NS...
# Fetching: BIKAJI.NS...
# Fetching: BIL.NS...
# Fetching: BILVYAPAR.NS...
# Fetching: BIOCON.NS...
# Fetching: BIOFILCHEM.NS...
# Fetching: BIRLACABLE.NS...
# Fetching: BIRLACORPN.NS...
# Fetching: BIRLAMONEY.NS...
# Fetching: BIRLANU.NS...
# Fetching: BLACKBUCK.NS...
# Fetching: BLAL.NS...
# Fetching: BLBLIMITED.NS...
# Fetching: BLISSGVS.NS...
# Fetching: BLKASHYAP.NS...
# Fetching: BLS.NS...
# Fetching: BLSE.NS...
# Fetching: BLUECHIP.NS...
# Fetching: BLUECOAST.NS...
# Fetching: BLUEDART.NS...
# Fetching: BLUEJET.NS...
# Fetching: BLUESTARCO.NS...
# Fetching: BLUESTONE.NS...
# Fetching: BLUSPRING.NS...
# Fetching: BMWVENTLTD.NS...
# Fetching: BODALCHEM.NS...
# Fetching: BOHRAIND.NS...
# Fetching: BOMDYEING.NS...
# Fetching: BORANA.NS...
# Fetching: BOROLTD.NS...
# Fetching: BORORENEW.NS...
# Fetching: BOROSCI.NS...
# Fetching: BOSCH-HCIL.NS...
# Fetching: BOSCHLTD.NS...
# Fetching: BPCL.NS...
# Fetching: BPL.NS...
# Fetching: BRIGADE.NS...
# Fetching: BRIGHOTEL.NS...
# Fetching: BRITANNIA.NS...
# Fetching: BRNL.NS...
# Fetching: BROOKS.NS...
# Fetching: BSE.NS...
# Fetching: BSHSL.NS...
# Fetching: BSL.NS...
# Fetching: BSOFT.NS...
# Fetching: BTML.NS...
# Fetching: BUILDPRO.NS...
# Fetching: BUTTERFLY.NS...
# Fetching: BVCL.NS...
# Fetching: BYKE.NS...
# Fetching: CALSOFT.NS...
# Fetching: CAMLINFINE.NS...
# Fetching: CAMPUS.NS...
# Fetching: CAMS.NS...
# Fetching: CANBK.NS...
# Fetching: CANFINHOME.NS...
# Fetching: CANHLIFE.NS...
# Fetching: CANTABIL.NS...
# Fetching: CAPACITE.NS...
# Fetching: CAPILLARY.NS...
# Fetching: CAPITALSFB.NS...
# Fetching: CAPLIPOINT.NS...
# Fetching: CAPTRUST.NS...
# Fetching: CARBORUNIV.NS...
# Fetching: CARERATING.NS...
# Fetching: CARRARO.NS...
# Fetching: CARTRADE.NS...
# Fetching: CARYSIL.NS...
# Fetching: CASTROLIND.NS...
# Fetching: CCCL.NS...
# Fetching: CCHHL.NS...
# Fetching: CCL.NS...
# Fetching: CDSL.NS...
# Fetching: CEATLTD.NS...
# Fetching: CEIGALL.NS...
# Fetching: CELEBRITY.NS...
# Fetching: CELLO.NS...
# Fetching: CEMPRO.NS...
# Fetching: CENTENKA.NS...
# Fetching: CENTEXT.NS...
# Fetching: CENTRALBK.NS...
# Fetching: CENTRUM.NS...
# Fetching: CENTUM.NS...
# Fetching: CENTURYPLY.NS...
# Fetching: CERA.NS...
# Fetching: CEREBRAINT.NS...
# Fetching: CESC.NS...
# Fetching: CEWATER.NS...
# Fetching: CGCL.NS...
# Fetching: CGPOWER.NS...
# Fetching: CHALET.NS...
# Fetching: CHAMBLFERT.NS...
# Fetching: CHEMBOND.NS...
# Fetching: CHEMBONDCH.NS...
# Fetching: CHEMCON.NS...
# Fetching: CHEMFAB.NS...
# Fetching: CHEMPLASTS.NS...
# Fetching: CHENNPETRO.NS...
# Fetching: CHEVIOT.NS...
# Fetching: CHOICEIN.NS...
# Fetching: CHOLAFIN.NS...
# Fetching: CHOLAHLDNG.NS...
# Fetching: CIEINDIA.NS...
# Fetching: CIFL.NS...
# Fetching: CIGNITITEC.NS...
# Fetching: CINELINE.NS...
# Fetching: CINEVISTA.NS...
# Fetching: CIPLA.NS...
# Fetching: CLEAN.NS...
# Fetching: CLEDUCATE.NS...
# Fetching: CLSEL.NS...
# Fetching: CMSINFO.NS...
# Fetching: CNL.NS...
# Fetching: COALINDIA.NS...
# Fetching: COASTCORP.NS...
# Fetching: COCHINSHIP.NS...
# Fetching: COFFEEDAY.NS...
# Fetching: COFORGE.NS...
# Fetching: COHANCE.NS...
# Fetching: COLPAL.NS...
# Fetching: COMPINFO.NS...
# Fetching: COMPUSOFT.NS...
# Fetching: COMSYN.NS...
# Fetching: CONCOR.NS...
# Fetching: CONCORDBIO.NS...
# Fetching: CONFIPET.NS...
# Fetching: CONSOFINVT.NS...
# Fetching: CONTROLPR.NS...
# Fetching: CORALFINAC.NS...
# Fetching: CORDSCABLE.NS...
# Fetching: COROMANDEL.NS...
# Fetching: CORONA.NS...
# Fetching: COSMOFIRST.NS...
# Fetching: COUNCODOS.NS...
# Fetching: CPCAP.NS...
# Fetching: CPEDU.NS...
# Fetching: CPPLUS.NS...
# Fetching: CRAFTSMAN.NS...
# Fetching: CRAMC.NS...
# Fetching: CREATIVEYE.NS...
# Fetching: CREDITACC.NS...
# Fetching: CREST.NS...
# Fetching: CRISIL.NS...
# Fetching: CRIZAC.NS...
# Fetching: CROMPTON.NS...
# Fetching: CROWN.NS...
# Fetching: CSBBANK.NS...
# Fetching: CSLFINANCE.NS...
# Fetching: CTE.NS...
# Fetching: CUB.NS...
# Fetching: CUBEXTUB.NS...
# Fetching: CUMMINSIND.NS...
# Fetching: CUPID.NS...
# Fetching: CURAA.NS...
# Fetching: CYBERMEDIA.NS...
# Fetching: CYBERTECH.NS...
# Fetching: CYIENT.NS...
# Fetching: CYIENTDLM.NS...
# Fetching: DABUR.NS...
# Fetching: DALBHARAT.NS...
# Fetching: DALMIASUG.NS...
# Fetching: DAMCAPITAL.NS...
# Fetching: DAMODARIND.NS...
# Fetching: DANGEE.NS...
# Fetching: DATAMATICS.NS...
# Fetching: DATAPATTNS.NS...
# Fetching: DAVANGERE.NS...
# Fetching: DBCORP.NS...
# Fetching: DBEIL.NS...
# Fetching: DBL.NS...
# Fetching: DBOL.NS...
# Fetching: DBREALTY.NS...
# Fetching: DBSTOCKBRO.NS...
# Fetching: DCAL.NS...
# Fetching: DCBBANK.NS...
# Fetching: DCI.NS...
# Fetching: DCM.NS...
# Fetching: DCMFINSERV.NS...
# Fetching: DCMNVL.NS...
# Fetching: DCMSHRIRAM.NS...
# Fetching: DCMSRIND.NS...
# Fetching: DCW.NS...
# Fetching: DCXINDIA.NS...
# Fetching: DDEVPLSTIK.NS...
# Fetching: DECCANCE.NS...
# Fetching: DEEDEV.NS...
# Fetching: DEEPAKFERT.NS...
# Fetching: DEEPAKNTR.NS...
# Fetching: DEEPINDS.NS...
# Fetching: DELHIVERY.NS...
# Fetching: DELPHIFX.NS...
# Fetching: DELTACORP.NS...
# Fetching: DELTAMAGNT.NS...
# Fetching: DEN.NS...
# Fetching: DENORA.NS...
# Fetching: DENTA.NS...
# Fetching: DEVIT.NS...
# Fetching: DEVX.NS...
# Fetching: DEVYANI.NS...
# Fetching: DGCONTENT.NS...
# Fetching: DHAMPURSUG.NS...
# Fetching: DHANBANK.NS...
# Fetching: DHANUKA.NS...
# Fetching: DHARAN.NS...
# Fetching: DHARMAJ.NS...
# Fetching: DHRUV.NS...
# Fetching: DHUNINV.NS...
# Fetching: DIACABS.NS...
# Fetching: DIAMINESQ.NS...
# Fetching: DIAMONDYD.NS...
# Fetching: DICIND.NS...
# Fetching: DIFFNKG.NS...
# Fetching: DIGIDRIVE.NS...
# Fetching: DIGISPICE.NS...
# Fetching: DIGITIDE.NS...
# Fetching: DIGJAMLMTD.NS...
# Fetching: DIL.NS...
# Fetching: DISHTV.NS...
# Fetching: DIVGIITTS.NS...
# Fetching: DIVISLAB.NS...
# Fetching: DIXON.NS...
# Fetching: DJML.NS...
# Fetching: DLF.NS...
# Fetching: DLINKINDIA.NS...
# Fetching: DMART.NS...
# Fetching: DMCC.NS...
# Fetching: DNAMEDIA.NS...
# Fetching: DODLA.NS...
# Fetching: DOLATALGO.NS...
# Fetching: DOLLAR.NS...
# Fetching: DOLPHIN.NS...
# Fetching: DOMS.NS...
# Fetching: DONEAR.NS...
# Fetching: DPABHUSHAN.NS...
# Fetching: DPSCLTD.NS...
# Fetching: DPWIRES.NS...
# Fetching: DRCSYSTEMS.NS...
# Fetching: DREAMFOLKS.NS...
# Fetching: DREDGECORP.NS...
# Fetching: DRREDDY.NS...
# Fetching: DSSL.NS...
# Fetching: DTIL.NS...
# Fetching: DUCON.NS...
# Fetching: DVL.NS...
# Fetching: DWARKESH.NS...
# Fetching: DYCL.NS...
# Fetching: DYNAMATECH.NS...
# Fetching: DYNPRO.NS...
# Fetching: E2E.NS...
# Fetching: EASEMYTRIP.NS...
# Fetching: EBGNG.NS...
# Fetching: ECLERX.NS...
# Fetching: ECOSMOBLTY.NS...
# Fetching: EDELWEISS.NS...
# Fetching: EFCIL.NS...
# Fetching: EICHERMOT.NS...
# Fetching: EIDPARRY.NS...
# Fetching: EIEL.NS...
# Fetching: EIFFL.NS...
# Fetching: EIHAHOTELS.NS...
# Fetching: EIHOTEL.NS...
# Fetching: EIMCOELECO.NS...
# Fetching: EKC.NS...
# Fetching: ELDEHSG.NS...
# Fetching: ELECON.NS...
# Fetching: ELECTCAST.NS...
# Fetching: ELECTHERM.NS...
# Fetching: ELGIEQUIP.NS...
# Fetching: ELGIRUBCO.NS...
# Fetching: ELIN.NS...
# Fetching: ELLEN.NS...
# Fetching: EMAMILTD.NS...
# Fetching: EMAMIPAP.NS...
# Fetching: EMAMIREAL.NS...
# Fetching: EMBDL.NS...
# Fetching: EMCURE.NS...
# Fetching: EMIL.NS...
# Fetching: EMKAY.NS...
# Fetching: EMMBI.NS...
# Fetching: EMMVEE.NS...
# Fetching: EMSLIMITED.NS...
# Fetching: EMUDHRA.NS...
# Fetching: ENDURANCE.NS...
# Fetching: ENERGYDEV.NS...
# Fetching: ENGINERSIN.NS...
# Fetching: ENIL.NS...
# Fetching: ENRIN.NS...
# Fetching: ENTERO.NS...
# Fetching: EPACK.NS...
# Fetching: EPACKPEB.NS...
# Fetching: EPIGRAL.NS...
# Fetching: EPL.NS...
# Fetching: EQUIPPP.NS...
# Fetching: EQUITASBNK.NS...
# Fetching: ERIS.NS...
# Fetching: ESABINDIA.NS...
# Fetching: ESAFSFB.NS...
# Fetching: ESCORTS.NS...
# Fetching: ESSARSHPNG.NS...
# Fetching: ESSENTIA.NS...
# Fetching: ESTER.NS...
# Fetching: ETERNAL.NS...
# Fetching: ETHOSLTD.NS...
# Fetching: EUREKAFORB.NS...
# Fetching: EUROBOND.NS...
# Fetching: EUROPRATIK.NS...
# Fetching: EUROTEXIND.NS...
# Fetching: EVEREADY.NS...
# Fetching: EVERESTIND.NS...
# Fetching: EXCEL.NS...
# ❌ Error fetching EXCEL.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: EXCELINDUS.NS...
# Fetching: EXCELSOFT.NS...
# Fetching: EXICOM.NS...
# Fetching: EXIDEIND.NS...
# Fetching: EXPLEOSOL.NS...
# Fetching: EXXARO.NS...
# Fetching: FABTECH.NS...
# Fetching: FACT.NS...
# Fetching: FAIRCHEMOR.NS...
# Fetching: FAZE3Q.NS...
# Fetching: FCL.NS...
# Fetching: FCSSOFT.NS...
# Fetching: FDC.NS...
# Fetching: FEDERALBNK.NS...
# Fetching: FEDFINA.NS...
# Fetching: FEL.NS...
# Fetching: FELDVR.NS...
# Fetching: FIBERWEB.NS...
# Fetching: FIEMIND.NS...
# Fetching: FILATEX.NS...
# Fetching: FILATFASH.NS...
# Fetching: FINCABLES.NS...
# Fetching: FINEORG.NS...
# Fetching: FINKURVE.NS...
# Fetching: FINOPB.NS...
# Fetching: FINPIPE.NS...
# Fetching: FIRSTCRY.NS...
# Fetching: FISCHER.NS...
# Fetching: FIVESTAR.NS...
# Fetching: FLAIR.NS...
# Fetching: FLEXITUFF.NS...
# Fetching: FLFL.NS...
# Fetching: FLUOROCHEM.NS...
# Fetching: FMGOETZE.NS...
# Fetching: FMNL.NS...
# Fetching: FOCUS.NS...
# Fetching: FOODSIN.NS...
# Fetching: FORCEMOT.NS...
# Fetching: FORTIS.NS...
# Fetching: FOSECOIND.NS...
# Fetching: FSL.NS...
# Fetching: FUSION.NS...
# Fetching: GABRIEL.NS...
# Fetching: GAEL.NS...
# Fetching: GAIL.NS...
# Fetching: GALAPREC.NS...
# Fetching: GALAXYSURF.NS...
# Fetching: GALLANTT.NS...
# Fetching: GANDHAR.NS...
# Fetching: GANDHITUBE.NS...
# Fetching: GANECOS.NS...
# Fetching: GANESHBE.NS...
# Fetching: GANESHCP.NS...
# Fetching: GANESHHOU.NS...
# Fetching: GANGAFORGE.NS...
# Fetching: GANGESSECU.NS...
# Fetching: GARFIBRES.NS...
# Fetching: GARUDA.NS...
# Fetching: GATECH.NS...
# Fetching: GATECHDVR.NS...
# Fetching: GATEWAY.NS...
# Fetching: GAYAHWS.NS...
# Fetching: GCSL.NS...
# Fetching: GEECEE.NS...
# Fetching: GEEKAYWIRE.NS...
# Fetching: GEMAROMA.NS...
# Fetching: GENCON.NS...
# Fetching: GENESYS.NS...
# Fetching: GENSOL.NS...
# Fetching: GENUSPAPER.NS...
# Fetching: GENUSPOWER.NS...
# Fetching: GEOJITFSL.NS...
# Fetching: GESHIP.NS...
# Fetching: GFLLIMITED.NS...
# Fetching: GHCL.NS...
# Fetching: GHCLTEXTIL.NS...
# Fetching: GICHSGFIN.NS...
# Fetching: GICRE.NS...
# Fetching: GILLANDERS.NS...
# Fetching: GILLETTE.NS...
# Fetching: GINNIFILA.NS...
# Fetching: GIPCL.NS...
# Fetching: GKENERGY.NS...
# Fetching: GKSL.NS...
# Fetching: GKWLIMITED.NS...
# Fetching: GLAND.NS...
# Fetching: GLAXO.NS...
# Fetching: GLENMARK.NS...
# Fetching: GLFL.NS...
# Fetching: GLOBAL.NS...
# Fetching: GLOBALE.NS...
# Fetching: GLOBALVECT.NS...
# Fetching: GLOBE.NS...
# Fetching: GLOBECIVIL.NS...
# Fetching: GLOBUSSPR.NS...
# Fetching: GLOSTERLTD.NS...
# Fetching: GLOTTIS.NS...
# Fetching: GMBREW.NS...
# Fetching: GMDCLTD.NS...
# Fetching: GMMPFAUDLR.NS...
# Fetching: GMRAIRPORT.NS...
# Fetching: GMRP&UI.NS...
# Fetching: GNA.NS...
# Fetching: GNFC.NS...
# Fetching: GOACARBON.NS...
# Fetching: GOCLCORP.NS...
# Fetching: GOCOLORS.NS...
# Fetching: GODAVARIB.NS...
# Fetching: GODFRYPHLP.NS...
# Fetching: GODIGIT.NS...
# Fetching: GODREJAGRO.NS...
# Fetching: GODREJCP.NS...
# Fetching: GODREJIND.NS...
# Fetching: GODREJPROP.NS...
# Fetching: GOKEX.NS...
# Fetching: GOKUL.NS...
# Fetching: GOKULAGRO.NS...
# Fetching: GOLDENTOBC.NS...
# Fetching: GOLDIAM.NS...
# Fetching: GOLDTECH.NS...
# Fetching: GOODLUCK.NS...
# Fetching: GOPAL.NS...
# Fetching: GOYALALUM.NS...
# Fetching: GPIL.NS...
# Fetching: GPPL.NS...
# Fetching: GPTHEALTH.NS...
# Fetching: GPTINFRA.NS...
# Fetching: GRANULES.NS...
# Fetching: GRAPHITE.NS...
# Fetching: GRASIM.NS...
# Fetching: GRAVITA.NS...
# Fetching: GREAVESCOT.NS...
# Fetching: GREENLAM.NS...
# Fetching: GREENPANEL.NS...
# Fetching: GREENPLY.NS...
# Fetching: GREENPOWER.NS...
# Fetching: GRINDWELL.NS...
# Fetching: GRINFRA.NS...
# Fetching: GRMOVER.NS...
# Fetching: GROBTEA.NS...
# Fetching: GROWW.NS...
# Fetching: GRPLTD.NS...
# Fetching: GRSE.NS...
# Fetching: GRWRHITECH.NS...
# Fetching: GSFC.NS...
# Fetching: GSLSU.NS...
# Fetching: GSPL.NS...
# Fetching: GSS.NS...
# Fetching: GTECJAINX.NS...
# Fetching: GTL.NS...
# Fetching: GTLINFRA.NS...
# Fetching: GTPL.NS...
# Fetching: GUFICBIO.NS...
# Fetching: GUJALKALI.NS...
# Fetching: GUJAPOLLO.NS...
# Fetching: GUJGASLTD.NS...
# Fetching: GUJRAFFIA.NS...
# Fetching: GUJTHEM.NS...
# Fetching: GULFOILLUB.NS...
# Fetching: GULFPETRO.NS...
# Fetching: GULPOLY.NS...
# Fetching: GVKPIL.NS...
# Fetching: GVPIL.NS...
# Fetching: GVPTECH.NS...
# Fetching: GVT&D.NS...
# Fetching: HAL.NS...
# Fetching: HALDER.NS...
# Fetching: HALEOSLABS.NS...
# Fetching: HAPPSTMNDS.NS...
# Fetching: HAPPYFORGE.NS...
# Fetching: HARDWYN.NS...
# Fetching: HARIOMPIPE.NS...
# Fetching: HARRMALAYA.NS...
# Fetching: HARSHA.NS...
# Fetching: HATHWAY.NS...
# Fetching: HATSUN.NS...
# Fetching: HAVELLS.NS...
# Fetching: HAVISHA.NS...
# Fetching: HBLENGINE.NS...
# Fetching: HBSL.NS...
# Fetching: HCC.NS...
# Fetching: HCG.NS...
# Fetching: HCL-INSYS.NS...
# Fetching: HCLTECH.NS...
# Fetching: HDBFS.NS...
# Fetching: HDFCAMC.NS...
# Fetching: HDFCBANK.NS...
# Fetching: HDFCLIFE.NS...
# Fetching: HDIL.NS...
# Fetching: HEADSUP.NS...
# Fetching: HECPROJECT.NS...
# Fetching: HEG.NS...
# Fetching: HEIDELBERG.NS...
# Fetching: HEMIPROP.NS...
# Fetching: HERANBA.NS...
# Fetching: HERITGFOOD.NS...
# Fetching: HEROMOTOCO.NS...
# Fetching: HESTERBIO.NS...
# Fetching: HEXATRADEX.NS...
# Fetching: HEXT.NS...
# Fetching: HFCL.NS...
# Fetching: HGINFRA.NS...
# Fetching: HGM.NS...
# Fetching: HGS.NS...
# Fetching: HIKAL.NS...
# Fetching: HILINFRA.NS...
# Fetching: HILTON.NS...
# Fetching: HIMATSEIDE.NS...
# Fetching: HINDALCO.NS...
# Fetching: HINDCOMPOS.NS...
# Fetching: HINDCON.NS...
# Fetching: HINDCOPPER.NS...
# Fetching: HINDOILEXP.NS...
# Fetching: HINDPETRO.NS...
# Fetching: HINDUNILVR.NS...
# Fetching: HINDWAREAP.NS...
# Fetching: HINDZINC.NS...
# Fetching: HIRECT.NS...
# Fetching: HISARMETAL.NS...
# Fetching: HITECH.NS...
# Fetching: HITECHCORP.NS...
# Fetching: HITECHGEAR.NS...
# Fetching: HLEGLAS.NS...
# Fetching: HLVLTD.NS...
# Fetching: HMAAGRO.NS...
# Fetching: HMT.NS...
# Fetching: HMVL.NS...
# Fetching: HNDFDS.NS...
# Fetching: HOMEFIRST.NS...
# Fetching: HONASA.NS...
# Fetching: HONAUT.NS...
# Fetching: HONDAPOWER.NS...
# Fetching: HPAL.NS...
# Fetching: HPIL.NS...
# Fetching: HPL.NS...
# Fetching: HSCL.NS...
# Fetching: HTMEDIA.NS...
# Fetching: HUBTOWN.NS...
# Fetching: HUDCO.NS...
# Fetching: HUHTAMAKI.NS...
# Fetching: HYBRIDFIN.NS...
# Fetching: HYUNDAI.NS...
# Fetching: IBULLSLTD.NS...
# Fetching: ICDSLTD.NS...
# Fetching: ICEMAKE.NS...
# Fetching: ICICIAMC.NS...
# Fetching: ICICIBANK.NS...
# Fetching: ICICIGI.NS...
# Fetching: ICICIPRULI.NS...
# Fetching: ICIL.NS...
# Fetching: ICRA.NS...
# Fetching: IDBI.NS...
# Fetching: IDEA.NS...
# Fetching: IDEAFORGE.NS...
# Fetching: IDFCFIRSTB.NS...
# Fetching: IEX.NS...
# Fetching: IFBAGRO.NS...
# Fetching: IFBIND.NS...
# Fetching: IFCI.NS...
# Fetching: IFGLEXPOR.NS...
# Fetching: IGARASHI.NS...
# Fetching: IGCL.NS...
# Fetching: IGIL.NS...
# Fetching: IGL.NS...
# Fetching: IGPL.NS...
# Fetching: IIFL.NS...
# Fetching: IIFLCAPS.NS...
# Fetching: IITL.NS...
# Fetching: IKIO.NS...
# Fetching: IKS.NS...
# Fetching: IL&FSENGG.NS...
# Fetching: IL&FSTRANS.NS...
# Fetching: IMAGICAA.NS...
# Fetching: IMFA.NS...
# Fetching: IMPAL.NS...
# Fetching: IMPEXFERRO.NS...
# Fetching: INCREDIBLE.NS...
# Fetching: INDBANK.NS...
# Fetching: INDGN.NS...
# Fetching: INDHOTEL.NS...
# Fetching: INDIACEM.NS...
# Fetching: INDIAGLYCO.NS...
# Fetching: INDIAMART.NS...
# Fetching: INDIANB.NS...
# Fetching: INDIANCARD.NS...
# Fetching: INDIANHUME.NS...
# Fetching: INDIASHLTR.NS...
# Fetching: INDIGO.NS...
# Fetching: INDIGOPNTS.NS...
# Fetching: INDIQUBE.NS...
# Fetching: INDNIPPON.NS...
# Fetching: INDOAMIN.NS...
# Fetching: INDOBORAX.NS...
# Fetching: INDOCO.NS...
# Fetching: INDOFARM.NS...
# Fetching: INDORAMA.NS...
# Fetching: INDOSTAR.NS...
# Fetching: INDOTECH.NS...
# Fetching: INDOTHAI.NS...
# Fetching: INDOUS.NS...
# Fetching: INDOWIND.NS...
# Fetching: INDRAMEDCO.NS...
# Fetching: INDSWFTLAB.NS...
# Fetching: INDTERRAIN.NS...
# Fetching: INDUSINDBK.NS...
# Fetching: INDUSTOWER.NS...
# Fetching: INFIBEAM.NS...
# ❌ Error fetching INFIBEAM.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: INFOBEAN.NS...
# Fetching: INFOMEDIA.NS...
# Fetching: INFY.NS...
# Fetching: INGERRAND.NS...
# Fetching: INNOVACAP.NS...
# Fetching: INNOVANA.NS...
# Fetching: INOXGREEN.NS...
# Fetching: INOXINDIA.NS...
# Fetching: INOXWIND.NS...
# Fetching: INSECTICID.NS...
# Fetching: INSPIRISYS.NS...
# Fetching: INTELLECT.NS...
# Fetching: INTENTECH.NS...
# Fetching: INTERARCH.NS...
# Fetching: INTLCONV.NS...
# Fetching: INVENTURE.NS...
# Fetching: IOB.NS...
# Fetching: IOC.NS...
# Fetching: IOLCP.NS...
# Fetching: IONEXCHANG.NS...
# Fetching: IPCALAB.NS...
# Fetching: IPL.NS...
# Fetching: IRB.NS...
# Fetching: IRCON.NS...
# Fetching: IRCTC.NS...
# Fetching: IREDA.NS...
# Fetching: IRFC.NS...
# Fetching: IRIS.NS...
# Fetching: IRISDOREME.NS...
# Fetching: IRMENERGY.NS...
# Fetching: ISFT.NS...
# Fetching: ISGEC.NS...
# Fetching: ISHANCH.NS...
# Fetching: ITC.NS...
# Fetching: ITCHOTELS.NS...
# Fetching: ITDC.NS...
# Fetching: ITI.NS...
# Fetching: IVALUE.NS...
# Fetching: IVC.NS...
# Fetching: IVP.NS...
# Fetching: IXIGO.NS...
# Fetching: IZMO.NS...
# Fetching: J&KBANK.NS...
# Fetching: JAGRAN.NS...
# Fetching: JAGSNPHARM.NS...
# Fetching: JAIBALAJI.NS...
# Fetching: JAICORPLTD.NS...
# Fetching: JAINREC.NS...
# Fetching: JAIPURKURT.NS...
# Fetching: JAMNAAUTO.NS...
# Fetching: JARO.NS...
# Fetching: JASH.NS...
# Fetching: JAYAGROGN.NS...
# Fetching: JAYBARMARU.NS...
# Fetching: JAYKAY.NS...
# Fetching: JAYNECOIND.NS...
# Fetching: JAYSREETEA.NS...
# Fetching: JBCHEPHARM.NS...
# Fetching: JBMA.NS...
# Fetching: JETFREIGHT.NS...
# Fetching: JGCHEM.NS...
# Fetching: JHS.NS...
# Fetching: JINDALPHOT.NS...
# Fetching: JINDALPOLY.NS...
# Fetching: JINDALSAW.NS...
# Fetching: JINDALSTEL.NS...
# Fetching: JINDRILL.NS...
# Fetching: JINDWORLD.NS...
# Fetching: JIOFIN.NS...
# Fetching: JISLDVREQS.NS...
# Fetching: JISLJALEQS.NS...
# Fetching: JITFINFRA.NS...
# Fetching: JKCEMENT.NS...
# Fetching: JKIL.NS...
# Fetching: JKIPL.NS...
# Fetching: JKLAKSHMI.NS...
# Fetching: JKPAPER.NS...
# Fetching: JKTYRE.NS...
# Fetching: JLHL.NS...
# Fetching: JMA.NS...
# Fetching: JMFINANCIL.NS...
# Fetching: JNKINDIA.NS...
# Fetching: JOCIL.NS...
# Fetching: JPOLYINVST.NS...
# Fetching: JPPOWER.NS...
# Fetching: JSFB.NS...
# Fetching: JSL.NS...
# Fetching: JSLL.NS...
# Fetching: JSWCEMENT.NS...
# Fetching: JSWENERGY.NS...
# Fetching: JSWHL.NS...
# Fetching: JSWINFRA.NS...
# Fetching: JSWSTEEL.NS...
# Fetching: JTEKTINDIA.NS...
# Fetching: JTLIND.NS...
# Fetching: JUBLCPL.NS...
# Fetching: JUBLFOOD.NS...
# Fetching: JUBLINGREA.NS...
# Fetching: JUBLPHARMA.NS...
# Fetching: JUNIPER.NS...
# Fetching: JUSTDIAL.NS...
# Fetching: JWL.NS...
# Fetching: JYOTHYLAB.NS...
# Fetching: JYOTICNC.NS...
# Fetching: JYOTISTRUC.NS...
# Fetching: KABRAEXTRU.NS...
# Fetching: KAJARIACER.NS...
# Fetching: KAKATCEM.NS...
# Fetching: KALAMANDIR.NS...
# Fetching: KALPATARU.NS...
# Fetching: KALYANI.NS...
# Fetching: KALYANIFRG.NS...
# Fetching: KALYANKJIL.NS...
# Fetching: KAMATHOTEL.NS...
# Fetching: KAMDHENU.NS...
# Fetching: KAMOPAINTS.NS...
# Fetching: KANANIIND.NS...
# Fetching: KANORICHEM.NS...
# Fetching: KANPRPLA.NS...
# Fetching: KANSAINER.NS...
# Fetching: KAPSTON.NS...
# Fetching: KARMAENG.NS...
# Fetching: KARURVYSYA.NS...
# Fetching: KAUSHALYA.NS...
# Fetching: KAVDEFENCE.NS...
# Fetching: KAYA.NS...
# Fetching: KAYNES.NS...
# Fetching: KCP.NS...
# Fetching: KCPSUGIND.NS...
# Fetching: KDDL.NS...
# Fetching: KEC.NS...
# Fetching: KECL.NS...
# Fetching: KEEPLEARN.NS...
# Fetching: KEI.NS...
# Fetching: KELLTONTEC.NS...
# Fetching: KERNEX.NS...
# Fetching: KESORAMIND.NS...
# Fetching: KEYFINSERV.NS...
# Fetching: KFINTECH.NS...
# Fetching: KHADIM.NS...
# Fetching: KHAICHEM.NS...
# Fetching: KHAITANLTD.NS...
# Fetching: KHANDSE.NS...
# Fetching: KICL.NS...
# Fetching: KILITCH.NS...
# Fetching: KIMS.NS...
# Fetching: KINGFA.NS...
# Fetching: KIOCL.NS...
# Fetching: KIRIINDUS.NS...
# Fetching: KIRLOSBROS.NS...
# Fetching: KIRLOSENG.NS...
# Fetching: KIRLOSIND.NS...
# Fetching: KIRLPNU.NS...
# Fetching: KITEX.NS...
# Fetching: KKCL.NS...
# Fetching: KMEW.NS...
# Fetching: KMSUGAR.NS...
# Fetching: KNAGRI.NS...
# Fetching: KNRCON.NS...
# Fetching: KOHINOOR.NS...
# Fetching: KOKUYOCMLN.NS...
# Fetching: KOLTEPATIL.NS...
# Fetching: KOPRAN.NS...
# Fetching: KOTAKBANK.NS...
# Fetching: KOTARISUG.NS...
# Fetching: KOTHARIPET.NS...
# Fetching: KOTHARIPRO.NS...
# Fetching: KPEL.NS...
# Fetching: KPIGREEN.NS...
# Fetching: KPIL.NS...
# Fetching: KPITTECH.NS...
# Fetching: KPRMILL.NS...
# Fetching: KRBL.NS...
# Fetching: KREBSBIO.NS...
# Fetching: KRIDHANINF.NS...
# Fetching: KRISHANA.NS...
# Fetching: KRISHIVAL.NS...
# Fetching: KRISHNADEF.NS...
# Fetching: KRITI.NS...
# Fetching: KRITIKA.NS...
# Fetching: KRITINUT.NS...
# Fetching: KRN.NS...
# Fetching: KRONOX.NS...
# Fetching: KROSS.NS...
# Fetching: KRSNAA.NS...
# Fetching: KRYSTAL.NS...
# Fetching: KSB.NS...
# Fetching: KSCL.NS...
# Fetching: KSHINTL.NS...
# Fetching: KSHITIJPOL.NS...
# Fetching: KSL.NS...
# Fetching: KSOLVES.NS...
# Fetching: KSR.NS...
# Fetching: KTKBANK.NS...
# Fetching: KUANTUM.NS...
# Fetching: LAGNAM.NS...
# Fetching: LAKPRE.NS...
# Fetching: LAL.NS...
# Fetching: LALPATHLAB.NS...
# Fetching: LAMBODHARA.NS...
# Fetching: LANCORHOL.NS...
# Fetching: LANDMARK.NS...
# Fetching: LAOPALA.NS...
# Fetching: LASA.NS...
# Fetching: LATENTVIEW.NS...
# Fetching: LATTEYS.NS...
# Fetching: LAURUSLABS.NS...
# Fetching: LAXMICOT.NS...
# Fetching: LAXMIDENTL.NS...
# Fetching: LAXMIINDIA.NS...
# Fetching: LCCINFOTEC.NS...
# Fetching: LEMERITE.NS...
# Fetching: LEMONTREE.NS...
# Fetching: LENSKART.NS...
# Fetching: LEXUS.NS...
# Fetching: LFIC.NS...
# Fetching: LGBBROSLTD.NS...
# Fetching: LGEINDIA.NS...
# Fetching: LGHL.NS...
# Fetching: LIBAS.NS...
# Fetching: LIBERTSHOE.NS...
# Fetching: LICHSGFIN.NS...
# Fetching: LICI.NS...
# Fetching: LIKHITHA.NS...
# Fetching: LINC.NS...
# Fetching: LINCOLN.NS...
# Fetching: LINDEINDIA.NS...
# Fetching: LLOYDSENGG.NS...
# Fetching: LLOYDSENT.NS...
# Fetching: LLOYDSME.NS...
# Fetching: LMW.NS...
# Fetching: LODHA.NS...
# Fetching: LOKESHMACH.NS...
# Fetching: LORDSCHLO.NS...
# Fetching: LOTUSDEV.NS...
# Fetching: LOTUSEYE.NS...
# Fetching: LOVABLE.NS...
# Fetching: LOYALTEX.NS...
# Fetching: LPDC.NS...
# Fetching: LT.NS...
# Fetching: LTF.NS...
# Fetching: LTFOODS.NS...
# Fetching: LTIM.NS...
# ❌ Error fetching LTIM.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: LTTS.NS...
# Fetching: LUMAXIND.NS...
# Fetching: LUMAXTECH.NS...
# Fetching: LUPIN.NS...
# Fetching: LUXIND.NS...
# Fetching: LXCHEM.NS...
# Fetching: LYKALABS.NS...
# Fetching: LYPSAGEMS.NS...
# Fetching: M&M.NS...
# Fetching: M&MFIN.NS...
# Fetching: MAANALU.NS...
# Fetching: MACPOWER.NS...
# Fetching: MADHAV.NS...
# Fetching: MADHUCON.NS...
# Fetching: MADRASFERT.NS...
# Fetching: MAGADSUGAR.NS...
# Fetching: MAGNUM.NS...
# Fetching: MAHABANK.NS...
# Fetching: MAHAPEXLTD.NS...
# Fetching: MAHASTEEL.NS...
# Fetching: MAHEPC.NS...
# Fetching: MAHESHWARI.NS...
# Fetching: MAHLIFE.NS...
# Fetching: MAHLOG.NS...
# Fetching: MAHSCOOTER.NS...
# Fetching: MAHSEAMLES.NS...
# Fetching: MAITHANALL.NS...
# Fetching: MALLCOM.NS...
# Fetching: MALUPAPER.NS...
# Fetching: MAMATA.NS...
# Fetching: MANAKALUCO.NS...
# Fetching: MANAKCOAT.NS...
# Fetching: MANAKSIA.NS...
# Fetching: MANAKSTEEL.NS...
# Fetching: MANALIPETC.NS...
# Fetching: MANAPPURAM.NS...
# Fetching: MANBA.NS...
# Fetching: MANCREDIT.NS...
# Fetching: MANGALAM.NS...
# Fetching: MANGLMCEM.NS...
# Fetching: MANINDS.NS...
# Fetching: MANINFRA.NS...
# Fetching: MANKIND.NS...
# Fetching: MANOMAY.NS...
# Fetching: MANORAMA.NS...
# Fetching: MANORG.NS...
# Fetching: MANUGRAPH.NS...
# Fetching: MANYAVAR.NS...
# Fetching: MAPMYINDIA.NS...
# Fetching: MARALOVER.NS...
# Fetching: MARATHON.NS...
# Fetching: MARICO.NS...
# Fetching: MARINE.NS...
# Fetching: MARKOLINES.NS...
# Fetching: MARKSANS.NS...
# Fetching: MARUTI.NS...
# Fetching: MASFIN.NS...
# Fetching: MASKINVEST.NS...
# Fetching: MASTEK.NS...
# Fetching: MASTERTR.NS...
# Fetching: MATRIMONY.NS...
# Fetching: MAWANASUG.NS...
# Fetching: MAXESTATES.NS...
# Fetching: MAXHEALTH.NS...
# Fetching: MAXIND.NS...
# Fetching: MAYURUNIQ.NS...
# Fetching: MAZDA.NS...
# Fetching: MAZDOCK.NS...
# Fetching: MBAPL.NS...
# Fetching: MBEL.NS...
# Fetching: MBLINFRA.NS...
# Fetching: MCL.NS...
# Fetching: MCLEODRUSS.NS...
# Fetching: MCLOUD.NS...
# Fetching: MCX.NS...
# Fetching: MEDANTA.NS...
# Fetching: MEDIASSIST.NS...
# Fetching: MEDICAMEQ.NS...
# Fetching: MEDICO.NS...
# Fetching: MEDPLUS.NS...
# Fetching: MEESHO.NS...
# Fetching: MEGASOFT.NS...
# ❌ Error fetching MEGASOFT.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: MEGASTAR.NS...
# Fetching: MEIL.NS...
# Fetching: MENONBE.NS...
# Fetching: MEP.NS...
# Fetching: METROBRAND.NS...
# Fetching: METROPOLIS.NS...
# Fetching: MFML.NS...
# Fetching: MFSL.NS...
# Fetching: MGEL.NS...
# Fetching: MGL.NS...
# Fetching: MHLXMIRU.NS...
# Fetching: MHRIL.NS...
# Fetching: MICEL.NS...
# Fetching: MIDHANI.NS...
# Fetching: MIDWESTLTD.NS...
# Fetching: MINDACORP.NS...
# Fetching: MINDTECK.NS...
# Fetching: MIRCELECTR.NS...
# Fetching: MIRZAINT.NS...
# Fetching: MITCON.NS...
# Fetching: MITTAL.NS...
# Fetching: MKPL.NS...
# Fetching: MMFL.NS...
# Fetching: MMP.NS...
# Fetching: MMTC.NS...
# Fetching: MOBIKWIK.NS...
# Fetching: MODINATUR.NS...
# Fetching: MODIRUBBER.NS...
# Fetching: MODIS.NS...
# Fetching: MODISONLTD.NS...
# Fetching: MODTHREAD.NS...
# Fetching: MOHITIND.NS...
# Fetching: MOIL.NS...
# Fetching: MOKSH.NS...
# Fetching: MOL.NS...
# Fetching: MOLDTECH.NS...
# Fetching: MOLDTKPAC.NS...
# Fetching: MONARCH.NS...
# Fetching: MONEYBOXX.NS...
# Fetching: MONTECARLO.NS...
# Fetching: MOREPENLAB.NS...
# Fetching: MOSCHIP.NS...
# Fetching: MOTHERSON.NS...
# Fetching: MOTILALOFS.NS...
# Fetching: MOTISONS.NS...
# Fetching: MOTOGENFIN.NS...
# Fetching: MPHASIS.NS...
# Fetching: MPSLTD.NS...
# Fetching: MRF.NS...
# Fetching: MRPL.NS...
# Fetching: MSPL.NS...
# Fetching: MSTCLTD.NS...
# Fetching: MSUMI.NS...
# Fetching: MTARTECH.NS...
# Fetching: MTEDUCARE.NS...
# Fetching: MTNL.NS...
# Fetching: MUFIN.NS...
# Fetching: MUFTI.NS...
# Fetching: MUKANDLTD.NS...
# Fetching: MUKKA.NS...
# Fetching: MUKTAARTS.NS...
# Fetching: MUNJALAU.NS...
# Fetching: MUNJALSHOW.NS...
# Fetching: MURUDCERA.NS...
# Fetching: MUTHOOTCAP.NS...
# Fetching: MUTHOOTFIN.NS...
# Fetching: MUTHOOTMF.NS...
# Fetching: MVGJL.NS...
# Fetching: MWL.NS...
# Fetching: NACLIND.NS...
# Fetching: NAGAFERT.NS...
# Fetching: NAGREEKCAP.NS...
# Fetching: NAGREEKEXP.NS...
# Fetching: NAHARCAP.NS...
# Fetching: NAHARINDUS.NS...
# Fetching: NAHARPOLY.NS...
# Fetching: NAHARSPING.NS...
# Fetching: NAM-INDIA.NS...
# Fetching: NARMADA.NS...
# Fetching: NATCAPSUQ.NS...
# Fetching: NATCOPHARM.NS...
# Fetching: NATHBIOGEN.NS...
# Fetching: NATIONALUM.NS...
# Fetching: NAUKRI.NS...
# Fetching: NAVA.NS...
# Fetching: NAVINFLUOR.NS...
# Fetching: NAVKARCORP.NS...
# Fetching: NAVKARURB.NS...
# Fetching: NAVNETEDUL.NS...
# Fetching: NAZARA.NS...
# Fetching: NBCC.NS...
# Fetching: NBIFIN.NS...
# Fetching: NCC.NS...
# Fetching: NCLIND.NS...
# Fetching: NDGL.NS...
# Fetching: NDL.NS...
# Fetching: NDLVENTURE.NS...
# Fetching: NDRAUTO.NS...
# Fetching: NDTV.NS...
# Fetching: NECCLTD.NS...
# Fetching: NECLIFE.NS...
# Fetching: NELCAST.NS...
# Fetching: NELCO.NS...
# Fetching: NEOGEN.NS...
# Fetching: NEPHROPLUS.NS...
# Fetching: NESCO.NS...
# Fetching: NESTLEIND.NS...
# Fetching: NETWEB.NS...
# Fetching: NETWORK18.NS...
# Fetching: NEULANDLAB.NS...
# Fetching: NEWGEN.NS...
# Fetching: NEXTMEDIA.NS...
# Fetching: NFL.NS...
# Fetching: NGIL.NS...
# Fetching: NGLFINE.NS...
# Fetching: NH.NS...
# Fetching: NHPC.NS...
# Fetching: NIACL.NS...
# Fetching: NIBE.NS...
# Fetching: NIBL.NS...
# Fetching: NIITLTD.NS...
# Fetching: NIITMTS.NS...
# Fetching: NILAINFRA.NS...
# Fetching: NILASPACES.NS...
# Fetching: NILKAMAL.NS...
# Fetching: NINSYS.NS...
# Fetching: NIPPOBATRY.NS...
# Fetching: NIRAJ.NS...
# Fetching: NIRAJISPAT.NS...
# Fetching: NITCO.NS...
# Fetching: NITINSPIN.NS...
# Fetching: NITIRAJ.NS...
# Fetching: NIVABUPA.NS...
# Fetching: NKIND.NS...
# Fetching: NLCINDIA.NS...
# Fetching: NMDC.NS...
# Fetching: NOCIL.NS...
# Fetching: NOIDATOLL.NS...
# Fetching: NORBTEAEXP.NS...
# Fetching: NORTHARC.NS...
# Fetching: NOVAAGRI.NS...
# Fetching: NPST.NS...
# Fetching: NRAIL.NS...
# Fetching: NRBBEARING.NS...
# Fetching: NRL.NS...
# Fetching: NSIL.NS...
# Fetching: NSLNISP.NS...
# Fetching: NTPC.NS...
# Fetching: NTPCGREEN.NS...
# Fetching: NUCLEUS.NS...
# Fetching: NURECA.NS...
# Fetching: NUVAMA.NS...
# Fetching: NUVOCO.NS...
# Fetching: NYKAA.NS...
# Fetching: OAL.NS...
# Fetching: OBCL.NS...
# Fetching: OBEROIRLTY.NS...
# Fetching: OCCLLTD.NS...
# Fetching: ODIGMA.NS...
# Fetching: OFSS.NS...
# Fetching: OIL.NS...
# Fetching: OILCOUNTUB.NS...
# Fetching: OLAELEC.NS...
# Fetching: OLECTRA.NS...
# Fetching: OMAXAUTO.NS...
# Fetching: OMAXE.NS...
# Fetching: OMFREIGHT.NS...
# Fetching: OMINFRAL.NS...
# Fetching: OMKARCHEM.NS...
# Fetching: ONELIFECAP.NS...
# Fetching: ONEPOINT.NS...
# Fetching: ONESOURCE.NS...
# Fetching: ONGC.NS...
# Fetching: ONMOBILE.NS...
# Fetching: ONWARDTEC.NS...
# Fetching: OPTIEMUS.NS...
# Fetching: ORBTEXP.NS...
# Fetching: ORCHASP.NS...
# Fetching: ORCHPHARMA.NS...
# Fetching: ORICONENT.NS...
# Fetching: ORIENTALTL.NS...
# Fetching: ORIENTBELL.NS...
# Fetching: ORIENTCEM.NS...
# Fetching: ORIENTCER.NS...
# Fetching: ORIENTELEC.NS...
# Fetching: ORIENTHOT.NS...
# Fetching: ORIENTLTD.NS...
# Fetching: ORIENTPPR.NS...
# Fetching: ORIENTTECH.NS...
# Fetching: ORISSAMINE.NS...
# Fetching: ORKLAINDIA.NS...
# Fetching: ORTINGLOBE.NS...
# Fetching: OSIAHYPER.NS...
# Fetching: OSWALAGRO.NS...
# Fetching: OSWALGREEN.NS...
# Fetching: OSWALPUMPS.NS...
# Fetching: OSWALSEEDS.NS...
# Fetching: PACEDIGITK.NS...
# Fetching: PAGEIND.NS...
# Fetching: PAISALO.NS...
# Fetching: PAKKA.NS...
# Fetching: PALASHSECU.NS...
# Fetching: PALREDTEC.NS...
# Fetching: PANACEABIO.NS...
# Fetching: PANACHE.NS...
# Fetching: PANAMAPET.NS...
# Fetching: PANSARI.NS...
# Fetching: PAR.NS...
# Fetching: PARACABLES.NS...
# Fetching: PARADEEP.NS...
# Fetching: PARAGMILK.NS...
# Fetching: PARAS.NS...
# Fetching: PARASPETRO.NS...
# Fetching: PARKHOSPS.NS...
# Fetching: PARKHOTELS.NS...
# Fetching: PARSVNATH.NS...
# Fetching: PASHUPATI.NS...
# Fetching: PASUPTAC.NS...
# Fetching: PATANJALI.NS...
# Fetching: PATELENG.NS...
# Fetching: PATELRMART.NS...
# Fetching: PATINTLOG.NS...
# Fetching: PAUSHAKLTD.NS...
# Fetching: PAVNAIND.NS...
# Fetching: PAYTM.NS...
# Fetching: PCBL.NS...
# Fetching: PCJEWELLER.NS...
# Fetching: PDMJEPAPER.NS...
# Fetching: PDSL.NS...
# Fetching: PEARLPOLY.NS...
# Fetching: PENIND.NS...
# Fetching: PENINLAND.NS...
# Fetching: PERSISTENT.NS...
# Fetching: PETRONET.NS...
# Fetching: PFC.NS...
# Fetching: PFIZER.NS...
# Fetching: PFOCUS.NS...
# Fetching: PFS.NS...
# Fetching: PGEL.NS...
# Fetching: PGHH.NS...
# Fetching: PGHL.NS...
# Fetching: PGIL.NS...
# Fetching: PHOENIXLTD.NS...
# Fetching: PICCADIL.NS...
# Fetching: PIDILITIND.NS...
# Fetching: PIGL.NS...
# Fetching: PIIND.NS...
# Fetching: PILANIINVS.NS...
# Fetching: PILITA.NS...
# Fetching: PINELABS.NS...
# Fetching: PIONEEREMB.NS...
# Fetching: PIRAMALFIN.NS...
# Fetching: PITTIENG.NS...
# Fetching: PIXTRANS.NS...
# Fetching: PKTEA.NS...
# Fetching: PLASTIBLEN.NS...
# Fetching: PLATIND.NS...
# Fetching: PLAZACABLE.NS...
# Fetching: PNB.NS...
# Fetching: PNBGILTS.NS...
# Fetching: PNBHOUSING.NS...
# Fetching: PNC.NS...
# Fetching: PNCINFRA.NS...
# Fetching: PNGJL.NS...
# Fetching: POCL.NS...
# Fetching: PODDARMENT.NS...
# Fetching: POKARNA.NS...
# Fetching: POLICYBZR.NS...
# Fetching: POLYCAB.NS...
# Fetching: POLYMED.NS...
# Fetching: POLYPLEX.NS...
# Fetching: PONNIERODE.NS...
# Fetching: POONAWALLA.NS...
# Fetching: POWERGRID.NS...
# Fetching: POWERINDIA.NS...
# Fetching: POWERMECH.NS...
# Fetching: PPAP.NS...
# Fetching: PPL.NS...
# Fetching: PPLPHARMA.NS...
# Fetching: PRABHA.NS...
# Fetching: PRAENG.NS...
# Fetching: PRAJIND.NS...
# Fetching: PRAKASH.NS...
# Fetching: PRAKASHSTL.NS...
# Fetching: PRAXIS.NS...
# Fetching: PRECAM.NS...
# Fetching: PRECOT.NS...
# Fetching: PRECWIRE.NS...
# Fetching: PREMEXPLN.NS...
# Fetching: PREMIER.NS...
# Fetching: PREMIERENE.NS...
# Fetching: PREMIERPOL.NS...
# Fetching: PRESTIGE.NS...
# Fetching: PRICOLLTD.NS...
# Fetching: PRIMESECU.NS...
# Fetching: PRIMO.NS...
# Fetching: PRINCEPIPE.NS...
# Fetching: PRITI.NS...
# Fetching: PRITIKAUTO.NS...
# Fetching: PRIVISCL.NS...
# Fetching: PROSTARM.NS...
# Fetching: PROTEAN.NS...
# Fetching: PROZONER.NS...
# Fetching: PRSMJOHNSN.NS...
# Fetching: PRUDENT.NS...
# Fetching: PRUDMOULI.NS...
# Fetching: PSB.NS...
# Fetching: PSPPROJECT.NS...
# Fetching: PTC.NS...
# Fetching: PTCIL.NS...
# Fetching: PTL.NS...
# Fetching: PUNJABCHEM.NS...
# Fetching: PURVA.NS...
# Fetching: PVP.NS...
# Fetching: PVRINOX.NS...
# Fetching: PVSL.NS...
# Fetching: PWL.NS...
# Fetching: PYRAMID.NS...
# Fetching: QPOWER.NS...
# Fetching: QUADFUTURE.NS...
# Fetching: QUESS.NS...
# Fetching: QUICKHEAL.NS...
# Fetching: RACE.NS...
# Fetching: RACLGEAR.NS...
# Fetching: RADAAN.NS...
# Fetching: RADHIKAJWE.NS...
# Fetching: RADIANTCMS.NS...
# Fetching: RADICO.NS...
# Fetching: RADIOCITY.NS...
# Fetching: RAILTEL.NS...
# Fetching: RAIN.NS...
# Fetching: RAINBOW.NS...
# Fetching: RAJESHEXPO.NS...
# Fetching: RAJMET.NS...
# Fetching: RAJOOENG.NS...
# Fetching: RAJRATAN.NS...
# Fetching: RAJRILTD.NS...
# Fetching: RAJSREESUG.NS...
# Fetching: RAJTV.NS...
# Fetching: RALLIS.NS...
# Fetching: RAMANEWS.NS...
# Fetching: RAMAPHO.NS...
# Fetching: RAMASTEEL.NS...
# Fetching: RAMCOCEM.NS...
# Fetching: RAMCOIND.NS...
# Fetching: RAMCOSYS.NS...
# Fetching: RAMKY.NS...
# Fetching: RAMRAT.NS...
# Fetching: RANASUG.NS...
# Fetching: RANEHOLDIN.NS...
# Fetching: RATEGAIN.NS...
# Fetching: RATNAMANI.NS...
# Fetching: RATNAVEER.NS...
# Fetching: RAYMOND.NS...
# Fetching: RAYMONDLSL.NS...
# Fetching: RAYMONDREL.NS...
# Fetching: RBA.NS...
# Fetching: RBLBANK.NS...
# Fetching: RBZJEWEL.NS...
# Fetching: RCF.NS...
# Fetching: RCOM.NS...
# Fetching: RECLTD.NS...
# Fetching: REDINGTON.NS...
# Fetching: REDTAPE.NS...
# Fetching: REFEX.NS...
# Fetching: REGAAL.NS...
# Fetching: REGENCERAM.NS...
# Fetching: RELAXO.NS...
# Fetching: RELCHEMQ.NS...
# Fetching: RELIABLE.NS...
# Fetching: RELIANCE.NS...
# Fetching: RELIGARE.NS...
# Fetching: RELTD.NS...
# Fetching: REMSONSIND.NS...
# Fetching: RENUKA.NS...
# Fetching: REPCOHOME.NS...
# Fetching: REPL.NS...
# Fetching: REPRO.NS...
# Fetching: RESPONIND.NS...
# Fetching: RETAIL.NS...
# Fetching: RGL.NS...
# Fetching: RHETAN.NS...
# Fetching: RHFL.NS...
# Fetching: RHIM.NS...
# Fetching: RHL.NS...
# Fetching: RICOAUTO.NS...
# Fetching: RIIL.NS...
# Fetching: RISHABH.NS...
# Fetching: RITCO.NS...
# Fetching: RITES.NS...
# Fetching: RKDL.NS...
# Fetching: RKEC.NS...
# Fetching: RKFORGE.NS...
# Fetching: RKSWAMY.NS...
# Fetching: RMDRIP.NS...
# Fetching: RML.NS...
# Fetching: RNBDENIMS.NS...
# Fetching: ROHLTD.NS...
# Fetching: ROLEXRINGS.NS...
# Fetching: ROLLT.NS...
# Fetching: ROML.NS...
# Fetching: ROSSARI.NS...
# Fetching: ROSSELLIND.NS...
# Fetching: ROSSTECH.NS...
# Fetching: ROTO.NS...
# Fetching: ROUTE.NS...
# Fetching: RPEL.NS...
# Fetching: RPGLIFE.NS...
# Fetching: RPOWER.NS...
# Fetching: RPPINFRA.NS...
# Fetching: RPPL.NS...
# Fetching: RPSGVENT.NS...
# Fetching: RPTECH.NS...
# Fetching: RRKABEL.NS...
# Fetching: RSSOFTWARE.NS...
# Fetching: RSWM.NS...
# Fetching: RSYSTEMS.NS...
# Fetching: RTNINDIA.NS...
# Fetching: RTNPOWER.NS...
# Fetching: RUBFILA.NS...
# Fetching: RUBICON.NS...
# Fetching: RUBYMILLS.NS...
# Fetching: RUCHINFRA.NS...
# Fetching: RUCHIRA.NS...
# Fetching: RUDRA.NS...
# Fetching: RUPA.NS...
# Fetching: RUSHIL.NS...
# Fetching: RUSTOMJEE.NS...
# Fetching: RVHL.NS...
# Fetching: RVNL.NS...
# Fetching: RVTH.NS...
# Fetching: S&SPOWER.NS...
# Fetching: SAATVIKGL.NS...
# Fetching: SABEVENTS.NS...
# Fetching: SABTNL.NS...
# ❌ Error fetching SABTNL.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: SADBHAV.NS...
# Fetching: SADBHIN.NS...
# Fetching: SADHNANIQ.NS...
# Fetching: SAFARI.NS...
# Fetching: SAGARDEEP.NS...
# Fetching: SAGCEM.NS...
# Fetching: SAGILITY.NS...
# Fetching: SAHYADRI.NS...
# Fetching: SAIL.NS...
# Fetching: SAILIFE.NS...
# Fetching: SAKAR.NS...
# Fetching: SAKHTISUG.NS...
# Fetching: SAKSOFT.NS...
# Fetching: SAKUMA.NS...
# Fetching: SALASAR.NS...
# Fetching: SALONA.NS...
# Fetching: SALSTEEL.NS...
# Fetching: SALZERELEC.NS...
# Fetching: SAMBHAAV.NS...
# Fetching: SAMBHV.NS...
# Fetching: SAMHI.NS...
# Fetching: SAMMAANCAP.NS...
# Fetching: SAMPANN.NS...
# Fetching: SANATHAN.NS...
# Fetching: SANCO.NS...
# Fetching: SANDESH.NS...
# Fetching: SANDHAR.NS...
# Fetching: SANDUMA.NS...
# Fetching: SANGAMIND.NS...
# Fetching: SANGHIIND.NS...
# Fetching: SANGHVIMOV.NS...
# Fetching: SANGINITA.NS...
# Fetching: SANOFI.NS...
# Fetching: SANOFICONR.NS...
# Fetching: SANSERA.NS...
# Fetching: SANSTAR.NS...
# Fetching: SANWARIA.NS...
# Fetching: SAPPHIRE.NS...
# Fetching: SARDAEN.NS...
# Fetching: SAREGAMA.NS...
# Fetching: SARLAPOLY.NS...
# Fetching: SARVESHWAR.NS...
# Fetching: SASKEN.NS...
# Fetching: SASTASUNDR.NS...
# Fetching: SATIA.NS...
# Fetching: SATIN.NS...
# Fetching: SAURASHCEM.NS...
# Fetching: SBC.NS...
# Fetching: SBCL.NS...
# Fetching: SBFC.NS...
# Fetching: SBGLP.NS...
# Fetching: SBICARD.NS...
# Fetching: SBILIFE.NS...
# Fetching: SBIN.NS...
# Fetching: SCHAEFFLER.NS...
# Fetching: SCHAND.NS...
# Fetching: SCHNEIDER.NS...
# Fetching: SCI.NS...
# Fetching: SCILAL.NS...
# Fetching: SCODATUBES.NS...
# Fetching: SCPL.NS...
# Fetching: SDBL.NS...
# Fetching: SEAMECLTD.NS...
# Fetching: SECMARK.NS...
# Fetching: SECURKLOUD.NS...
# Fetching: SEJALLTD.NS...
# Fetching: SELMC.NS...
# Fetching: SEMAC.NS...
# Fetching: SENCO.NS...
# Fetching: SENORES.NS...
# Fetching: SEPC.NS...
# Fetching: SERVOTECH.NS...
# Fetching: SESHAPAPER.NS...
# Fetching: SETCO.NS...
# Fetching: SETL.NS...
# Fetching: SETUINFRA.NS...
# Fetching: SEYAIND.NS...
# Fetching: SFL.NS...
# Fetching: SGFIN.NS...
# Fetching: SGIL.NS...
# Fetching: SGL.NS...
# Fetching: SGMART.NS...
# Fetching: SHAH.NS...
# Fetching: SHAHALLOYS.NS...
# Fetching: SHAILY.NS...
# Fetching: SHAKTIPUMP.NS...
# Fetching: SHALBY.NS...
# Fetching: SHALPAINTS.NS...
# Fetching: SHANKARA.NS...
# Fetching: SHANTI.NS...
# Fetching: SHANTIGEAR.NS...
# Fetching: SHANTIGOLD.NS...
# Fetching: SHARDACROP.NS...
# Fetching: SHARDAMOTR.NS...
# Fetching: SHAREINDIA.NS...
# Fetching: SHEKHAWATI.NS...
# Fetching: SHEMAROO.NS...
# Fetching: SHILCTECH.NS...
# Fetching: SHILPAMED.NS...
# Fetching: SHIVALIK.NS...
# Fetching: SHIVAMAUTO.NS...
# Fetching: SHIVAMILLS.NS...
# Fetching: SHIVATEX.NS...
# Fetching: SHIVAUM.NS...
# Fetching: SHK.NS...
# Fetching: SHOPERSTOP.NS...
# Fetching: SHRADHA.NS...
# Fetching: SHREDIGCEM.NS...
# Fetching: SHREECEM.NS...
# Fetching: SHREEJISPG.NS...
# Fetching: SHREEPUSHK.NS...
# Fetching: SHREERAMA.NS...
# Fetching: SHRENIK.NS...
# Fetching: SHREYANIND.NS...
# Fetching: SHRINGARMS.NS...
# Fetching: SHRIPISTON.NS...
# Fetching: SHRIRAMFIN.NS...
# Fetching: SHRIRAMPPS.NS...
# Fetching: SHYAMCENT.NS...
# Fetching: SHYAMMETL.NS...
# Fetching: SHYAMTEL.NS...
# Fetching: SICALLOG.NS...
# Fetching: SIEMENS.NS...
# Fetching: SIGACHI.NS...
# Fetching: SIGIND.NS...
# Fetching: SIGMA.NS...
# Fetching: SIGNATURE.NS...
# Fetching: SIGNPOST.NS...
# Fetching: SIKKO.NS...
# Fetching: SIL.NS...
# Fetching: SILGO.NS...
# Fetching: SILGO-RE1.NS...
# ❌ Error fetching SILGO-RE1.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: SILINV.NS...
# Fetching: SILLYMONKS.NS...
# Fetching: SILVERTUC.NS...
# Fetching: SIMBHALS.NS...
# Fetching: SIMPLEXINF.NS...
# Fetching: SINCLAIR.NS...
# Fetching: SINDHUTRAD.NS...
# Fetching: SINTERCOM.NS...
# Fetching: SIRCA.NS...
# Fetching: SIS.NS...
# Fetching: SITINET.NS...
# Fetching: SIYSIL.NS...
# Fetching: SJS.NS...
# Fetching: SJVN.NS...
# Fetching: SKFINDIA.NS...
# Fetching: SKFINDUS.NS...
# Fetching: SKIPPER.NS...
# Fetching: SKMEGGPROD.NS...
# Fetching: SKYGOLD.NS...
# Fetching: SMARTLINK.NS...
# Fetching: SMARTWORKS.NS...
# Fetching: SMCGLOBAL.NS...
# Fetching: SMLMAH.NS...
# Fetching: SMLT.NS...
# Fetching: SMSPHARMA.NS...
# Fetching: SNOWMAN.NS...
# Fetching: SOBHA.NS...
# Fetching: SOFTTECH.NS...
# Fetching: SOLARA.NS...
# Fetching: SOLARINDS.NS...
# Fetching: SOLARWORLD.NS...
# Fetching: SOLEX.NS...
# Fetching: SOMANYCERA.NS...
# Fetching: SOMATEX.NS...
# Fetching: SOMICONVEY.NS...
# Fetching: SONACOMS.NS...
# Fetching: SONAMLTD.NS...
# Fetching: SONATSOFTW.NS...
# Fetching: SOTL.NS...
# Fetching: SOUTHBANK.NS...
# Fetching: SOUTHWEST.NS...
# Fetching: SPAL.NS...
# Fetching: SPANDANA.NS...
# Fetching: SPARC.NS...
# Fetching: SPCENET.NS...
# Fetching: SPECIALITY.NS...
# Fetching: SPECTRUM.NS...
# Fetching: SPENCERS.NS...
# Fetching: SPIC.NS...
# Fetching: SPLIL.NS...
# Fetching: SPLPETRO.NS...
# Fetching: SPMLINFRA.NS...
# Fetching: SPORTKING.NS...
# Fetching: SRD.NS...
# Fetching: SREEL.NS...
# Fetching: SRF.NS...
# Fetching: SRGHFL.NS...
# Fetching: SRHHYPOLTD.NS...
# Fetching: SRM.NS...
# Fetching: SRPL.NS...
# Fetching: SSDL.NS...
# Fetching: SSWL.NS...
# Fetching: STALLION.NS...
# Fetching: STANLEY.NS...
# Fetching: STAR.NS...
# Fetching: STARCEMENT.NS...
# Fetching: STARHEALTH.NS...
# Fetching: STARPAPER.NS...
# Fetching: STARTECK.NS...
# Fetching: STCINDIA.NS...
# Fetching: STEELCAS.NS...
# Fetching: STEELCITY.NS...
# Fetching: STEELXIND.NS...
# Fetching: STEL.NS...
# Fetching: STERTOOLS.NS...
# Fetching: STLNETWORK.NS...
# Fetching: STLTECH.NS...
# Fetching: STOVEKRAFT.NS...
# Fetching: STUDDS.NS...
# Fetching: STYL.NS...
# Fetching: STYLAMIND.NS...
# Fetching: STYLEBAAZA.NS...
# Fetching: STYRENIX.NS...
# Fetching: SUBEXLTD.NS...
# Fetching: SUBROS.NS...
# Fetching: SUDARCOLOR.NS...
# Fetching: SUDARSCHEM.NS...
# Fetching: SUDEEPPHRM.NS...
# Fetching: SUKHJITS.NS...
# Fetching: SULA.NS...
# Fetching: SUMEETINDS.NS...
# Fetching: SUMICHEM.NS...
# Fetching: SUMIT.NS...
# Fetching: SUMMITSEC.NS...
# Fetching: SUNCLAY.NS...
# Fetching: SUNDARAM.NS...
# Fetching: SUNDARMFIN.NS...
# Fetching: SUNDRMBRAK.NS...
# Fetching: SUNDRMFAST.NS...
# Fetching: SUNDROP.NS...
# Fetching: SUNFLAG.NS...
# Fetching: SUNPHARMA.NS...
# Fetching: SUNTECK.NS...
# Fetching: SUNTV.NS...
# Fetching: SUPERHOUSE.NS...
# Fetching: SUPERSPIN.NS...
# Fetching: SUPRAJIT.NS...
# Fetching: SUPREME.NS...
# Fetching: SUPREMEIND.NS...
# Fetching: SUPREMEINF.NS...
# Fetching: SUPRIYA.NS...
# Fetching: SURAJEST.NS...
# Fetching: SURAJLTD.NS...
# Fetching: SURAKSHA.NS...
# Fetching: SURANASOL.NS...
# Fetching: SURANAT&P.NS...
# Fetching: SURYALAXMI.NS...
# Fetching: SURYAROSNI.NS...
# Fetching: SURYODAY.NS...
# Fetching: SUTLEJTEX.NS...
# Fetching: SUVEN.NS...
# Fetching: SUVIDHAA.NS...
# Fetching: SUYOG.NS...
# Fetching: SUZLON.NS...
# Fetching: SVLL.NS...
# Fetching: SVPGLOB.NS...
# Fetching: SWANCORP.NS...
# Fetching: SWARAJENG.NS...
# Fetching: SWELECTES.NS...
# Fetching: SWIGGY.NS...
# Fetching: SWSOLAR.NS...
# Fetching: SYMPHONY.NS...
# Fetching: SYNCOMF.NS...
# Fetching: SYNGENE.NS...
# Fetching: SYRMA.NS...
# Fetching: SYSTMTXC.NS...
# Fetching: TAINWALCHM.NS...
# Fetching: TAJGVK.NS...
# Fetching: TAKE.NS...
# Fetching: TALBROAUTO.NS...
# Fetching: TANLA.NS...
# Fetching: TARACHAND.NS...
# Fetching: TARAPUR.NS...
# Fetching: TARC.NS...
# Fetching: TARIL.NS...
# Fetching: TARMAT.NS...
# Fetching: TARSONS.NS...
# Fetching: TASTYBITE.NS...
# Fetching: TATACAP.NS...
# Fetching: TATACHEM.NS...
# Fetching: TATACOMM.NS...
# Fetching: TATACONSUM.NS...
# Fetching: TATAELXSI.NS...
# Fetching: TATAINVEST.NS...
# Fetching: TATAPOWER.NS...
# Fetching: TATASTEEL.NS...
# Fetching: TATATECH.NS...
# Fetching: TATVA.NS...
# Fetching: TBOTEK.NS...
# Fetching: TBZ.NS...
# Fetching: TCI.NS...
# Fetching: TCIEXP.NS...
# Fetching: TCIFINANCE.NS...
# Fetching: TCPLPACK.NS...
# Fetching: TCS.NS...
# Fetching: TDPOWERSYS.NS...
# Fetching: TEAMGTY.NS...
# Fetching: TEAMLEASE.NS...
# Fetching: TECHM.NS...
# Fetching: TECHNOE.NS...
# Fetching: TECILCHEM.NS...
# Fetching: TEGA.NS...
# Fetching: TEJASNET.NS...
# Fetching: TEMBO.NS...
# Fetching: TENNIND.NS...
# Fetching: TERASOFT.NS...
# Fetching: TEXINFRA.NS...
# Fetching: TEXMOPIPES.NS...
# Fetching: TEXRAIL.NS...
# Fetching: TFCILTD.NS...
# Fetching: TFL.NS...
# Fetching: TGBHOTELS.NS...
# Fetching: THANGAMAYL.NS...
# Fetching: THEINVEST.NS...
# Fetching: THEJO.NS...
# Fetching: THELEELA.NS...
# Fetching: THEMISMED.NS...
# Fetching: THERMAX.NS...
# Fetching: THOMASCOOK.NS...
# Fetching: THOMASCOTT.NS...
# Fetching: THYROCARE.NS...
# Fetching: TI.NS...
# Fetching: TICL.NS...
# Fetching: TIGERLOGS.NS...
# Fetching: TIIL.NS...
# Fetching: TIINDIA.NS...
# Fetching: TIJARIA.NS...
# Fetching: TIL.NS...
# Fetching: TIMETECHNO.NS...
# Fetching: TIMKEN.NS...
# Fetching: TINNARUBR.NS...
# Fetching: TIPSFILMS.NS...
# Fetching: TIPSMUSIC.NS...
# Fetching: TIRUMALCHM.NS...
# Fetching: TIRUPATIFL.NS...
# Fetching: TITAGARH.NS...
# Fetching: TITAN.NS...
# Fetching: TMB.NS...
# Fetching: TMCV.NS...
# Fetching: TMPV.NS...
# Fetching: TNPETRO.NS...
# Fetching: TNPL.NS...
# Fetching: TNTELE.NS...
# Fetching: TOKYOPLAST.NS...
# Fetching: TOLINS.NS...
# Fetching: TORNTPHARM.NS...
# Fetching: TORNTPOWER.NS...
# Fetching: TOTAL.NS...
# Fetching: TOUCHWOOD.NS...
# Fetching: TPHQ.NS...
# Fetching: TPLPLASTEH.NS...
# Fetching: TRACXN.NS...
# Fetching: TRANSRAILL.NS...
# Fetching: TRANSWORLD.NS...
# Fetching: TRAVELFOOD.NS...
# Fetching: TREEHOUSE.NS...
# Fetching: TREJHARA.NS...
# Fetching: TREL.NS...
# Fetching: TRENT.NS...
# Fetching: TRF.NS...
# Fetching: TRIDENT.NS...
# Fetching: TRIGYN.NS...
# Fetching: TRITURBINE.NS...
# Fetching: TRIVENI.NS...
# Fetching: TRU.NS...
# Fetching: TRUALT.NS...
# Fetching: TSFINV.NS...
# Fetching: TTKHLTCARE.NS...
# Fetching: TTKPRESTIG.NS...
# Fetching: TTL.NS...
# Fetching: TTML.NS...
# Fetching: TVSELECT.NS...
# Fetching: TVSHLTD.NS...
# Fetching: TVSMOTOR.NS...
# Fetching: TVSSCS.NS...
# Fetching: TVSSRICHAK.NS...
# Fetching: TVTODAY.NS...
# Fetching: TVVISION.NS...
# Fetching: UBL.NS...
# Fetching: UCAL.NS...
# Fetching: UCOBANK.NS...
# Fetching: UDS.NS...
# Fetching: UFBL.NS...
# Fetching: UFLEX.NS...
# Fetching: UFO.NS...
# Fetching: UGARSUGAR.NS...
# Fetching: UGROCAP.NS...
# Fetching: UJJIVANSFB.NS...
# Fetching: ULTRACEMCO.NS...
# Fetching: UMAEXPORTS.NS...
# Fetching: UMESLTD.NS...
# Fetching: UMIYA-MRO.NS...
# Fetching: UNICHEMLAB.NS...
# Fetching: UNIDT.NS...
# Fetching: UNIECOM.NS...
# Fetching: UNIENTER.NS...
# Fetching: UNIINFO.NS...
# Fetching: UNIMECH.NS...
# Fetching: UNIONBANK.NS...
# Fetching: UNIPARTS.NS...
# Fetching: UNITDSPR.NS...
# Fetching: UNITECH.NS...
# Fetching: UNITEDPOLY.NS...
# Fetching: UNITEDTEA.NS...
# Fetching: UNIVASTU.NS...
# Fetching: UNIVCABLES.NS...
# Fetching: UNIVPHOTO.NS...
# Fetching: UNOMINDA.NS...
# Fetching: UPL.NS...
# Fetching: URAVIDEF.NS...
# Fetching: URBANCO.NS...
# Fetching: URJA.NS...
# Fetching: USHAMART.NS...
# Fetching: USK.NS...
# Fetching: UTIAMC.NS...
# Fetching: UTKARSHBNK.NS...
# Fetching: UTLSOLAR.NS...
# Fetching: UTTAMSUGAR.NS...
# Fetching: UYFINCORP.NS...
# Fetching: V2RETAIL.NS...
# Fetching: VADILALIND.NS...
# Fetching: VAIBHAVGBL.NS...
# Fetching: VAISHALI.NS...
# Fetching: VAKRANGEE.NS...
# Fetching: VALIANTLAB.NS...
# Fetching: VALIANTORG.NS...
# Fetching: VARDHACRLC.NS...
# Fetching: VARDMNPOLY.NS...
# Fetching: VARROC.NS...
# Fetching: VASCONEQ.NS...
# Fetching: VASWANI.NS...
# Fetching: VBL.NS...
# Fetching: VCL.NS...
# Fetching: VEDL.NS...
# Fetching: VEEDOL.NS...
# Fetching: VENKEYS.NS...
# Fetching: VENTIVE.NS...
# Fetching: VENUSPIPES.NS...
# Fetching: VENUSREM.NS...
# Fetching: VERANDA.NS...
# Fetching: VERTOZ.NS...
# Fetching: VESUVIUS.NS...
# Fetching: VETO.NS...
# Fetching: VGL.NS...
# Fetching: VGUARD.NS...
# Fetching: VHL.NS...
# Fetching: VHLTD.NS...
# Fetching: VIDHIING.NS...
# Fetching: VIDYAWIRES.NS...
# Fetching: VIJAYA.NS...
# Fetching: VIJIFIN.NS...
# Fetching: VIKASECO.NS...
# Fetching: VIKASLIFE.NS...
# Fetching: VIKRAMSOLR.NS...
# Fetching: VIKRAN.NS...
# Fetching: VIMTALABS.NS...
# Fetching: VINATIORGA.NS...
# Fetching: VINCOFE.NS...
# Fetching: VINDHYATEL.NS...
# Fetching: VINEET-RE.NS...
# ❌ Error fetching VINEET-RE.NS (Skipping): 'NoneType' object has no attribute 'text'
# Fetching: VINEETLAB.NS...
# Fetching: VINNY.NS...
# Fetching: VINYLINDIA.NS...
# Fetching: VIPCLOTHNG.NS...
# Fetching: VIPIND.NS...
# Fetching: VIPULLTD.NS...
# Fetching: VIRINCHI.NS...
# Fetching: VISAKAIND.NS...
# Fetching: VISASTEEL.NS...
# Fetching: VISHNU.NS...
# Fetching: VISHWARAJ.NS...
# Fetching: VIVIDHA.NS...
# Fetching: VIVIMEDLAB.NS...
# Fetching: VIYASH.NS...
# Fetching: VLEGOV.NS...
# Fetching: VLSFINANCE.NS...
# Fetching: VMART.NS...
# Fetching: VMM.NS...
# Fetching: VMSTMT.NS...
# Fetching: VOLTAMP.NS...
# Fetching: VOLTAS.NS...
# Fetching: VPRPL.NS...
# Fetching: VRAJ.NS...
# Fetching: VRLLOG.NS...
# Fetching: VSSL.NS...
# Fetching: VSTIND.NS...
# Fetching: VSTL.NS...
# Fetching: VSTTILLERS.NS...
# Fetching: VTL.NS...
# Fetching: WAAREEENER.NS...
# Fetching: WAAREEINDO.NS...
# Fetching: WAAREERTL.NS...
# Fetching: WABAG.NS...
# Fetching: WAKEFIT.NS...
# Fetching: WALCHANNAG.NS...
# Fetching: WANBURY.NS...
# Fetching: WCIL.NS...
# Fetching: WEALTH.NS...
# Fetching: WEBELSOLAR.NS...
# Fetching: WEIZMANIND.NS...
# Fetching: WEL.NS...
# Fetching: WELCORP.NS...
# Fetching: WELENT.NS...
# Fetching: WELINV.NS...
# Fetching: WELSPUNLIV.NS...
# Fetching: WENDT.NS...
# Fetching: WESTLIFE.NS...
# Fetching: WEWIN.NS...
# Fetching: WEWORK.NS...
# Fetching: WHEELS.NS...
# Fetching: WHIRLPOOL.NS...
# Fetching: WILLAMAGOR.NS...
# Fetching: WINDLAS.NS...
# Fetching: WINDMACHIN.NS...
# Fetching: WINSOME.NS...
# Fetching: WIPL.NS...
# Fetching: WIPRO.NS...
# Fetching: WOCKPHARMA.NS...
# Fetching: WONDERLA.NS...
# Fetching: WORTHPERI.NS...
# Fetching: WSI.NS...
# Fetching: WSTCSTPAPR.NS...
# Fetching: XCHANGING.NS...
# Fetching: XELPMOC.NS...
# Fetching: XPROINDIA.NS...
# Fetching: XTGLOBAL.NS...
# Fetching: YASHO.NS...
# Fetching: YATHARTH.NS...
# Fetching: YATRA.NS...
# Fetching: YESBANK.NS...
# Fetching: YUKEN.NS...
# Fetching: ZAGGLE.NS...
# Fetching: ZEEL.NS...
# Fetching: ZEELEARN.NS...
# Fetching: ZEEMEDIA.NS...
# Fetching: ZENITHEXPO.NS...
# Fetching: ZENITHSTL.NS...
# Fetching: ZENSARTECH.NS...
# Fetching: ZENTEC.NS...
# Fetching: ZFCVINDIA.NS...
# Fetching: ZIMLAB.NS...
# Fetching: ZODIAC.NS...
# Fetching: ZODIACLOTH.NS...
# Fetching: ZOTA.NS...
# Fetching: ZUARI.NS...
# Fetching: ZUARIIND.NS...
# Fetching: ZYDUSLIFE.NS...
# Fetching: ZYDUSWELL.NS...

# %%
final_sector_df.to_csv('sector_df.csv')

# %%
final_sector_df
# Out:
#           SYMBOL              Sector
# 0      20MICRONS     Basic Materials
# 1     21STCENMGM  Financial Services
# 2         360ONE  Financial Services
# 3      3IINFOLTD          Technology
# 4        3MINDIA         Industrials
# ...          ...                 ...
# 2224        ZOTA          Healthcare
# 2225       ZUARI     Basic Materials
# 2226    ZUARIIND         Industrials
# 2227   ZYDUSLIFE          Healthcare
# 2228   ZYDUSWELL  Consumer Defensive
#
# [2229 rows x 2 columns]

# %%
final_data = data.merge(final_sector_df,on='SYMBOL',how='left')

# %%
final_data.to_csv('stock_list.csv')
